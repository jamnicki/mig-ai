# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm

from transformers import AutoTokenizer, AutoModel

from src.data.dataset import GlossSeq2PolishDataset
from src.data.utils import iter_dto_as_dicts
from src.settings import PREPROCESSED_DIR, EMBEDDINGS_DIR

tqdm.pandas()

# %%
dataset = GlossSeq2PolishDataset()

# %%
polish_annotations = (record.polish_annotation for record in dataset)
polish_df = pd.DataFrame.from_records(iter_dto_as_dicts(polish_annotations))
polish_df
# Out:
#         start     end                                               text  \
# 0       39040   41120                  Myślę, że mam inny pomysł, można?
# 1       41120   49680  Chyba ten znak mówi, że jak ktoś będzie spacer...
# 2       49680   55280  Trzeba przejść łukiem obok leżącego i o tym zn...
# 3       61280   66840  Okrągły znak pomaga nam, mówi, że są pasy na u...
# 4       66840   73200  Jak ktoś zobaczy, ale zignoruje ten znak, to m...
# ...       ...     ...                                                ...
# 39618  248960  250320                                  [uderzanie w coś]
# 39619  279560  291400  Kot zobaczył w akwarium rybkę. Podszedł i dał ...
# 39620  291400  347120                                  Zjadłam, zjadłam.
# 39621  347120  356440  Zając biegnie, zobaczył wiszące pranie. Wskocz...
# 39622  359240  361760         Kombinezon dziecka, tak na siebie założył.
#
#                            doc_filepath  video_filename task_label
# 0      /15/K66BF13-26_15_15_signsNO.eaf  K66BF13-26.mp4         15
# 1      /15/K66BF13-26_15_15_signsNO.eaf  K66BF13-26.mp4         15
# 2      /15/K66BF13-26_15_15_signsNO.eaf  K66BF13-26.mp4         15
# 3      /15/K66BF13-26_15_15_signsNO.eaf  K66BF13-26.mp4         15
# 4      /15/K66BF13-26_15_15_signsNO.eaf  K66BF13-26.mp4         15
# ...                                 ...             ...        ...
# 39618   /13/K17BF13-26_13_13_comics.eaf  K17BF13-26.mp4         13
# 39619   /13/K17BF13-26_13_13_comics.eaf  K17BF13-26.mp4         13
# 39620   /13/K17BF13-26_13_13_comics.eaf  K17BF13-26.mp4         13
# 39621   /13/K17BF13-26_13_13_comics.eaf  K17BF13-26.mp4         13
# 39622   /13/K17BF13-26_13_13_comics.eaf  K17BF13-26.mp4         13
#
# [39623 rows x 6 columns]

# %%
to_be_augmented_df = polish_df.sample(frac=0.5, random_state=42)
to_be_augmented_df
# Out:
#         start     end                                               text  \
# 9044   800200  801520                              Są mrugające światła.
# 39448   58240   58720                                       Przepraszam.
# 6326   109320  109960                                                Ja.
# 3502    55840   58640            Otwierać, tam widać samochód, tak, tak.
# 198    290880  293840                        Może, następny jest skuter.
# ...       ...     ...                                                ...
# 994    307720  313960  Jest rower, rower wraz z dzieckiem, rower z pr...
# 29129   69040   70280                                 Mam dalej oglądać.
# 4600    84800   85920                                      Są tam głusi.
# 32638  117520  123600  Sowa wystaje z drzewa i jest zła, pyta, co tak...
# 3817   233520  234480                                            Nie ma.
#
#                                   doc_filepath  video_filename task_label
# 9044          /15/K42AF01-15_15_15_signsNO.eaf  K42AF01-15.mp4         15
# 39448          /13/K60AF13-26_13_13_comics.eaf  K60AF13-26.mp4         13
# 6326          /15/K11AF15-26_15_15_signsNO.eaf  K11AF15-26.mp4         15
# 3502          /15/K04AF15-26_15_15_signsNO.eaf  K04AF15-26.mp4         15
# 198           /15/K75AF13-26_15_15_signsNO.eaf  K75AF13-26.mp4         15
# ...                                        ...             ...        ...
# 994           /15/K69AF11-26_15_15_signsNO.eaf  K69AF11-26.mp4         15
# 29129  /08/K25AF01-17_08_frog_08_frog_frog.eaf  K25AF01-17.mp4         08
# 4600          /15/K74AF12-26_15_15_signsNO.eaf  K74AF12-26.mp4         15
# 32638  /08/K21AF01-16_08_frog_08_frog_frog.eaf  K21AF01-16.mp4         08
# 3817          /15/K21BF01-16_15_15_signsNO.eaf  K21BF01-16.mp4         15
#
# [19812 rows x 6 columns]

# %% [markdown]
# ## Separate annotations into .txt files

# %%
# TO_AUGMENT_TXTS_DIR = PREPROCESSED_DIR / 'to_augment_txts/'
# TO_AUGMENT_TXTS_DIR.mkdir(exist_ok=True)


# for index, row in to_be_augmented_df.iterrows():
#     print(index, row['text'])

#     with open(TO_AUGMENT_TXTS_DIR / f'{index}.txt', 'w') as f:
#         f.write(row['text'])
    
#     # break
# Out:
# 9044 Są mrugające światła.
# 39448 Przepraszam.
# 6326 Ja.
# 3502 Otwierać, tam widać samochód, tak, tak.
# 198 Może, następny jest skuter.
# 20040 Wiesz gdzie jest Mc Donald’s?
# 8966 Specjalnie zamówiony u krawcowej.
# 33502 Więc chłopiec zagląda tam i sprawdza.
# 16542 Ja w weekendy jestem wolna.
# 33903 Chodzi w kółko i myśli.
# 13951 Jeden z nich bierze zamach.
# 21763 Popołudniu o czwartej.
# 12527 Strażak ma specjalny topór do wyważenia drzwi. Już się zamierza, ale przerywa, bo alarm wyłączył się.
# 12387 On idzie na górę. Przygotowuje kołdrę, myje się i przebiera.
# 11562 Zakaz biegania tam, gdzie są zaparkowane samochody.
# 37455 Jest miska z jabłkami.
# 37936 Podchodzi kot i chce do niej zbliżyć się pyszczkiem, żeby ją powąchać.
# 17000 Mogę umówić się z tobą dwudziestego trzeciego lutego po godzinie czwartej.
# 23080 Policjant idzie dalej i zauważa pana, który montuje okno.
# 7449 Myślę.
# 16517 Spotkać się po to by załatwić sprawy związane z podpisem dokumentów.
# 6233 Kask założony bardziej do tyłu, żeby powietrze chłodziło głowę, ale wtedy pasek coraz mocniej uciska brodę.
# 14944 Mnie pasuje i tu i tu, dwudziestego trzeciego i dwudziestego piątego.
# 5165 Musi być na stojąco.
# 32322 Dobrze.
# 14777 Dwudziesty siódmy.
# 22417 Drugiego.
# 7954 Na przykład…
# 36376 Ma jabłko na głowie i boi się.
# 31310 Chłopiec również je zauważa.
# 38659 Miś zobaczył, że płot zniknął.
# 11658 Praca.
# 13804 To się okazało.
# 30778 Tam chciałby zjeść ptaszka.
# 4193 Myślę, że ten znak oznacza zakaz kąpieli pod prysznicem.
# 4556 Na skuter też nie.
# 24105 Jemu znikł ten kosz, a oni sobie poszli.
# 39007 Rybka patrzy i atakuje kota, a on się przestraszył.
# 34181 Ma całe mokre ubranie.
# 33989 Żabę?
# 33573 Była duża przestrzeń.
# 22300 Nie mogę, zwariowałabym!
# 31595 Patrzył przez lornetkę na jego klatkę.
# 38208 Słychać cisza.
# 23753 Szyba pękła, a on wrócił do taty, żeby zobaczyć co robi.
# 25422 Dwa są pełne.
# 35121 Następnie.
# 39364 Chłopak prosi: nie!
# 28588 Pan podrapał się po głowie.
# 31640 Na końcu kot trafia prosto do kręgielni.
# 26196 Chłopcy pomagają zbierać gruszki do kosza.
# 10359 Twoje i moje.
# 38792 I stawia go na głowie.
# 35049 A gdy miała małe jabłko, bała się.
# 37960 Godzina dziesiąta...
# 7762 To niebezpieczne.
# 22298 Ciągle siedzisz w domu!
# 27625 Wszystkie gruszki, w trakcie upadku chłopca, wysypały się na ulicę.
# 4824 Na kolei rozmawiają przez krótkofalówki.
# 37193 Był w wielkim szoku.
# 3102 Mam zamigać o każdym?
# 3935 Można powiedzieć, przesadzać z jedzeniem.
# 21803 Nie możesz.
# 8889 To okropne.
# 37087 Pan wraca z miasta do domu.
# 18278 Dwudziestego siódmego wolne.
# 1911 Nie należy tak robić.
# 29177 Te wszystkie obrazki zapamiętałam.
# 13655 Jeden chłopak poczuł się zmęczony i mówi: “Jestem zmęczony, idę na górę spać”.
# 20870 Ja przez ten cały tydzień, przez ten cały tydzień mam wolne tylko w niedzielę.
# 32531 Mama, tata i malutkie żabki.
# 14647 Masz wolne?
# 12261 A jeden chłopiec jest bardzo zmęczony, naoglądał się już.
# 28263 Widzi, że facet na górze zbiera gruszki.
# 32354 Kot bierze lornetkę i patrząc przez nią, rozgląda się po okolicy.
# 16135 Po. Może.
# 9220 Prysznic jest za mały.
# 30667 Pszczoły gonią psa.
# 10436 Sam pod prysznicem - nie.
# 13847 Przechodzą wszyscy do jadalni, na spotkanie.
# 23166 Chłopak, zauroczony, zagapia się i przewraca. Spada z roweru.
# 5697 Tak.
# 34440 Była żaba w czymś i wyskoczyła, zniknęła, ktoś jej szuka.
# 1467 Gdzie na przykład?
# 17757 Będę miał coraz to inne kobiety.
# 29857 Ona uderza kota, a ten wylatuje i upada na ziemię.
# 2055 Uwaga na bawiące się dzieci, żeby się nie utopiły.
# 8504 Specjalna góra.
# 6018 Myślę, że może to oznaczać piłowanie siedzenia w celu dokuczenia komuś, żeby spadł z siedzenia.
# 29268 Żabie udaje się wyskoczyć ze słoika. Uciekła, nie ma już żaby.
# 31072 Połknął tę kulę.
# 8901 To normalne.
# 5227 To chyba dotyczy… taka śluza.
# 12364 Mówi, że pójdzie sam.
# 9349 Co to jest?
# 24232 …nosidło na szyby z pasami na ramionach.
# 32666 W drugim domu był kot.
# 5775 To na pewno rodzice ich nie pilnują.
# 20627 Lepiej swobodnie zaplanować rozmowę, żeby pasowało.
# 9172 Z trzech zostało dwa.
# 7557 Niebezpieczny upadek.
# 38080 Przepraszam, drugi raz.
# 27645 Tata ubrał plecak i wyszedł.
# 31385 Zobaczyli ul pszczół wiszący na drzewie, ale nie było tam żaby.
# 6334 Właśnie.
# 34536 Bierze jedną żabę do ręki, macha, żegna się, odchodzi.
# 18592 Hej, hej, hej, a w środę, trzeciego, jestem w kinie od szóstej trzydzieści do dziewiątej trzydzieści.
# 17099 Nie ma.
# 14505 A po pracy nie masz co robić.
# 21466 W poniedziałek mam wolne.
# 30401 Ucieka i krzyczy.
# 1557 Nie.
# 28446 Jabłka poukładane.
# 1174 Koń nie może być na ulicy.
# 20494 Pogadać o babskich sprawach. Może być?
# 1457 Nie wolno zbliżać się do linii.
# 11895 Jadą daleko i docierają do Włoch.
# 33046 Wchodzi na drzewo.
# 25137 Obok mały chłopczyk, cztero-, pięcio-, sześcio- lub siedmioletni.
# 29581 Idzie dalej i widzi pień powalonego drzewa.
# 8141 Jakiś materiał.
# 17213 Tak.
# 29826 Urodziła dużo dzieci.
# 12609 Następnego dnia mężczyzna schodzi na dół, a znajomi patrzą na niego. "Patrzą na mnie? Co jest?"
# 9128 Albo… albo…
# 11532 Zadowolony.
# 7725 Dlaczego to jest?
# 30674 Już, nie ma więcej, to wszystko.
# 31574 Biegnie tam szybko, pies go wyrzuca.
# 4974 Może.
# 15335 Praca, sprzątanie.
# 20347 Pracujesz, a ja mam wolne.
# 24404 Trzech chłopaków też odchodzi.
# 21748 Ja do szóstej pracuję.
# 15252 Czy będą pasować.
# 36417 Ptak o godzinie 12 wyskoczył z zegara i ukradł wszystkie jabłka.
# 37033 Szybko pobiegła.
# 3933 Nie wierzę, nie wierzę…
# 3693 Para nie może się trzymać za ręce.
# 6603 To jest źle.
# 5746 Nie wolno wchodzić z jedzeniem.
# 35213 Myszka Miki dziwi się.
# 22608 Jest.
# 35328 Myszka ignoruje budzik i odwraca się do niego plecami, wystawiając w jego stronę dupę.
# 20591 Sport, konkurs, tak.
# 18638 Co robisz w piątek, sobotę i niedzielę, szóstego… piątego, szóstego i siódmego?
# 36407 Zabrakło części płotu.
# 37284 Obudził się, bo budzik dzwonił.
# 28505 Potem nadjeżdża następna osoba - to chłopiec na rowerze.
# 13608 Potem jakiś chłopak mówi, że jest zmęczony i idzie na górę spać.
# 10277 Człowiek upada.
# 21766 Wolne.
# 13104 Nie będą przeszkadzać, bo tam ktoś jest zmęczony i śpi.
# 10873 Koń nie może się kąpać pod prysznicem.
# 15024 Rano o ósmej wyjeżdżam.
# 24763 Starsza pani pyta ile kosztuje naprawa.
# 21616 Ja o czwartej trzydzieści idę…
# 27953 Ale mógł im dać po jednej gruszce za pomoc w zbieraniu.
# 29983 Ptak to zauważył.
# 18654 Moment.
# 34127 Idą dalej i szukają aż natknęli się na drzewo, była dziura to bawili się, a na górze był ul pszczeli.
# 32183 Dziecko siedziało jeleniowi na głowie, ten go strącił i spadło.
# 15044 Co robisz dwunastego lutego?
# 2622 Woda śmierdzi i jest brudna, to dlatego nie wolno kąpać się w wannie.
# 28773 Nadjeżdża chłopiec na rowerze, zauważa kosze z gruszkami i chciałby ukraść jedną.
# 10696 Zakaz wejścia w biustonoszu może oznaczać nakaz ubrania się.
# 17686 Smutno mi.
# 22546 Poniedziałek, wtorek, środa, ja mam wybierać?
# 21613 Dobrze.
# 36292 Tata idzie, zauważa, że brakuje kawałka płotu.
# 25036 Charlie nie zauważył policjanta z tyłu i rzuca za siebie kit.
# 23747 Akurat dobrze, że się pojawił.
# 14009 Następny.
# 26444 Montuje szybę w oknie.
# 5223 Też z alkoholem, wyrzucają, jest niebezpieczeństwo utonięcia.
# 8492 Ale jest znak, że trzeba uważać, ten znak jest na przykład w pociągu albo w metrze.
# 12950 Szukali we wszystkich pokojach hotelowych.
# 5523 W Egipcie trzeba zakrywać całe ciało.
# 22471 O dziewiętnastej ja…
# 26222 Okno pęka, a chłopak odchodzi.
# 28887 Chłopiec oddala się na rowerze.
# 34060 Już skończył i siedzi.
# 17407 Gdzie?
# 27385 Okno pęka od rzuconego kamienia.
# 38267 Wyłącza go, zamyka oczy i nakrywa kołdrą głowę.
# 16822 Pod tytułem...
# 34599 Kot wszedł z powrotem przez rynnę.
# 15755 Widzisz i obserwujesz.
# 26381 Babcia, której rozbito okno, wychodzi z domu, widzi rozbite okno.
# 27872 Wyrzucał gruszki z kieszeni… miał czerwoną chustkę na szyi.
# 15315 Pasowało.
# 31481 Przyszły małe żabki. Sześć albo siedem.
# 15054 Dobrze, to się umówimy na kawę?
# 4530 Niebezpieczeństwo wypadku.
# 6556 Wiesz, ten szkielet.
# 33145 Idą sobie.
# 15320 Fryzjer nie pasuje.
# 15363 Nie.
# 550 Wanna nigdy nie stoi w parku.
# 6839 A tam, gdzie są ławki i jest blisko do śmietnika, wolno jeść.
# 13160 Nic.
# 2290 Akurat tutaj konie muszą się kąpać osobo, może to o to chodzi.
# 25956 Policjant patrzy i zastanawia się.
# 9831 Jest ogrodzenie i nie powinno się tam wchodzić.
# 14524 O szóstej.
# 13469 A koledzy mówią mu: O, jesteś!
# 34969 Już wiem.
# 30983 Ptaszek głośno krzyczy, lata w kółko i ucieka.
# 7070 Nie, to jest tramwaj.
# 6666 Chyba chodzi o pływanie.
# 35496 Idzie zając z olbrzymimi uszami. A tam na sznurze wisi pranie.
# 21558 Trudno.
# 13062 A on jest głuchy i twardo spał
# 37429 Wstać, wstać.
# 734 Zakaz alkoholu i jeść też nie wolno, choćbyś umierał z głodu, nie wolno.
# 20250 W czwartek zawsze robię zakupy w sklepie.
# 4955 Nie, odwrotnie.
# 32140 Przygotowują, wiesz, szklany słoik.
# 25456 Inny chłopak przejeżdża na rowerze.
# 32209 Pies próbował ją wywęszyć.
# 3269 Myślę, że to chyba żart.
# 32231 A tam za kamieniem było zwierzę, którego nie zauważył.
# 27868 Mężczyzna, pan, wchodzi na drzewo i zbiera gruszki.
# 28223 Ma iść gdzieś na miasto, jest mały, więc rzuca w niskie okna rozbijając je.
# 17355 W piątek dwudziestego szóstego lutego.
# 13958 Następnego dnia wszyscy zeszli na dół i poszli na śniadanie.
# 4775 Gorąca lampa.
# 9527 Praca.
# 22526 O osiemnastej.
# 16734 Można?
# 9389 Miejsce zakazu to może być na przykład plaża i tam się opalać.
# 19147 Mam wolne. Akurat o czwartej kończę pracę, a potem mam wolne.
# 22283 Tak lepiej i jest wygodniej, bo w niedzielę będę zmęczona.
# 13185 Do autokaru wsiedli głusi i słyszący.
# 4504 Wypadek.
# 21476 Potem mam dwie godziny wolne do dziewiętnastej.
# 23022 Akurat niedaleko stało trzech chłopców, widzieli, co się stało.
# 7840 Czy można zanieść prysznic na pole? Nie?
# 21090 Gdzie?
# 26286 Charlie kazał chłopcu iść i znowu wybić gdzieś szybę.
# 34319 Chłopiec szuka, przeszukuje ubranie.
# 4093 Dobrze.
# 7528 Można wpaść i się utopić, nie ma się czego złapać, są fale.
# 20734 Nie ma rozmowy.
# 28790 Liczy kosze, są dwa, a jeden zniknął.
# 24475 Charlie Chaplin był niższy od niego.
# 8406 Hamburger do jedzenia i napój z procentami.
# 14584 Nie ma, jest praca.
# 5100 Brudna woda.
# 27803 Chłopiec odwraca się i przez to nieuważanie trafia na kamień i przewraca się, a gruszki porozrzucane są.
# 17983 A dwudziestego trzeciego na kawę.
# 1464 Tak.
# 26664 Potem idą sobie i koniec.
# 17673 Koniec.
# 24357 Jeden kosz był pusty, drugi pełny, a trzeciego brakowało.
# 32142 Chłopiec nakrywa się kołdrą.
# 33829 Wchodzi na górę środkiem rynny.
# 30967 Patrzy przez lornetkę z otwartym pyskiem.
# 35158 Następnie dwunasta. Dwunasta.
# 11843 Ładnie.
# 5536 Na ulicy obowiązuje zakaz noszenia bikini.
# 15000 Sobota, szóstego?
# 2893 Napój…
# 7827 Dobrze, już.
# 12421 Wszyscy patrzą na niego, a on pyta: “Co się stało?”
# 29549 Kot przygotował się i zaczął wchodzić wnętrzem rynny na górę.
# 23090 Kto to jest?
# 28003 Wszyscy patrzą na chłopca.
# 15938 Ja nie mogę, nie, przepraszam.
# 19424 Zaplanować tak, żeby twoje i moje dzieci były razem.
# 23338 Widzi, że dwa kosze są pełne.
# 37989 Dobrze.
# 465 Tak, ok.
# 38677 Do kobiety.
# 26690 Trzech innych chłopców oglądają to całe zdarzenie.
# 32505 Wyskoczył i rozbił szklany pojemnik.
# 38948 Rozbije się i się pobrudzisz.
# 9152 Człowiek spłonął, pozostały tylko nogi, reszta była popiołem.
# 4152 Pewnie nie wolno jeść gorącego hamburgera w muzeum albo nad morzem, przez unoszący się zapach i innym to przeszkadza, dotyczy również alkoholu.
# 12357 Są tam Głusi i słyszący.
# 18291 Sprytne pytanie do mnie.
# 9647 Nie wolno piłować, bo to niszczy.
# 12560 Potem byli bardzo zmęczeni i zasnęli.
# 29270 Szukali i nie ma! Pies wsadził głowę w słoik i wygląda przez okno.
# 37729 Dobrze, można postawić na głowie dużą kulę.
# 9571 Z “Gongu” przenieśli się do “Samowaru”.
# 37697 Kot chce się zemścić na rybce.
# 38990 Jak to się rybce udało?
# 6600 Nie ma znaku i jest duży ruch pieszych.
# 19269 Aha.
# 32079 Kładzie się spać i zasypia.
# 2133 Ty jesteś dumny.
# 17780 Krowie placki.
# 20467 Tak? Naprawdę, w ten piątek?
# 15004 Zamówienia, zamówienia…
# 15920 Kiedy indziej masz wolne?
# 32623 Już.
# 24522 Udaje, że nic się nie dzieje.
# 22683 Hm.
# 8156 Żółty znak w kształcie trójkąta informuje, że można się poślizgnąć, widzę, że jest jeszcze strzałka w dół.
# 16359 Poczekaj, wolne mam…
# 18494 Albo… w czwartek nie mogę.
# 18336 Sto, tak.
# 5595 Mowę czytać z ust.
# 36535 Dwie myszki stoją w ogrodzie, przy żółtym płocie.
# 5373 Ludzie nie słuchają.
# 32289 Pszczoły lecą, a oni uciekają.
# 23640 Pan odwiązuje z szyi chustę i czyści nią gruszkę.
# 8618 Prywatnie piłować sobie ławkę, nie ma takiego znaku.
# 21624 Od czwartej trzydzieści do dziewiątej wieczorem uczę się do egzaminu.
# 16930 Chodźmy na imprezę.
# 13741 Dziwne.
# 29637 Kot ucieka.
# 24717 Chłopiec odłożył rower, zauważył stojące kosze. Mężczyzna był nadal zajęty zbieraniem gruszek.
# 33003 Zasypia.
# 32346 Ptak go zauważył.
# 10091 Jak on spiłuje drzewo, to drzewo się złamie i on spadnie, to niebezpieczne.
# 19492 Wólczańska.
# 11262 Hulajnoga...
# 18986 Wyjeżdżam w góry.
# 2308 Kąpać się nie wolno.
# 30567 Chłopiec przytulił psa i powiedział, nie wolno.
# 109 Pytam, jak pada deszcz to są ludzie, którzy idą normalnie w deszczu.
# 10622 Zatrucie.
# 740 Że na przykład jak rozstawi namiot to nie wolno mu mieć jedzenia i postawić kontenerka z wódką.
# 14286 Od ósmej.
# 32159 Chłopak widzi dwie żaby, które siedzą obok siebie na pniu drzewa, otoczone przez szereg małych żabek.
# 35798 Wskazówka się przesuwa.
# 33033 Pies merda ogonem.
# 12774 Syreny wyją.
# 38399 Mocno.
# 30145 Przychodzi babcia i przepędza kota.
# 21899 Do szóstej, a o szóstej trzydzieści mam niemiecki.
# 22326 Nam nie pasuje!
# 23811 Jeden kosz jest pełny, drugi, środkowy, też pełny, trzeci do połowy.
# 10755 Trzeba uważać.
# 19106 Później mogę.
# 29096 Zadowolony kot zostawił lornetkę i szybko zbiega na dół po schodach. Wychodzi z bloku i wbiega do bloku, w którym mieszka ptaszek. Ale ktoś go stamtąd wyrzuca na ulicę.
# 24250 Smarkacz przygląda się z ukrycia.
# 31476 Jeleń nagle się zatrzymał i mały człowiek spadł.
# 37533 Napluła na niego, a on otrzepał się i uciekł.
# 17851 Może jest, że kończysz o siedemnastej?
# 7831 Wykrzyknik informuje, że pociągi nadjeżdżają w obu kierunkach. Trzeba uważać przed przejazdem przez tory.
# 34571 W klatce była huśtawka.
# 5662 Do wanny.
# 37570 Wskakuje w nie i skacze dalej.
# 4741 Myć się najpierw pod prysznicem.
# 3875 Utonięcie.
# 10612 Ześlizguje się…
# 13954 Okazało się, że ktoś palił papierosy i czujnik wykrył dym.
# 2608 Prąd.
# 24534 Mały chłopiec uciekł.
# 28928 Chłopiec się otrzepuje, boli go kolano.
# 8725 NIe, zakaz może dotyczy fontanny, nie wolno tam się kąpać, jest zakaz.
# 12029 Następnego dnia mężczyzna ubrał się i zjechał windą na dół.
# 25454 Pan znowu wchodzi na drzewo.
# 28025 Trzej chłopcy podchodzą gryząc gruszki.
# 31314 Gdzieś dziurą w ziemi, nie wiem.
# 33089 Ale zauważa żabie dzieci, bardzo ładne małe żabki.
# 24857 Potem schodzi z drabiny.
# 38297 Coś okrągłego na głowie.
# 39226 Królik.
# 15864 Jesteś wolna.
# 34563 Wytrzymał to.
# 14014 Zastanawiam się.
# 24291 Tak zarabiali.
# 6056 Tak, tak, było.
# 11904 Dobra.
# 39202 Muzyka.
# 1784 Jest źle zaprojektowany.
# 29678 Pies włożył tam łeb.
# 15381 Brawo.
# 31036 Kamera śledzi jej ruch.
# 1763 Nie ma.
# 16862 Aha.
# 36126 Mała Myszka Miki.
# 35484 Myszka Miki wciąż śpi, z wystającą pupą.
# 2299 Tak, tak może o to chodzi.
# 31043 Wpada tam.
# 33761 Po drugiej stronie, w klatce jest mały ptaszek.
# 12538 A głusi widzą go i wołają: “Ooo!”.
# 38312 Myszka Miki.
# 29478 Chłopiec otwiera słój, w którego środku siedzi żaba.
# 28896 Są dwa, a trzeciego brakuje.
# 10968 Dobrze, dobrze, zgadzam się.
# 17056 Możemy spotkać o godzinie szesnastej trzydzieści do osiemnastej trzydzieści.
# 10798 Nie wolno chodzić wokół osobom postronnym.
# 31075 Kręgle, tak.
# 39033 Królik biega.
# 30948 Kot stanął i zadowolony pomachał do ptaszka.
# 10608 Gdzie się wspina?
# 16257 Jestem umówiony... tak, jedenastego lutego.
# 34873 Koniec.
# 6892 Amen.
# 7729 Pociągi jeżdżą bardzo szybko, sto pięćdziesiąt, dwieście kilometrów.
# 16583 Wyjeżdżam nad morze, na urlop.
# 9830 Siatka.
# 15035 Dobrze wiesz, jaka ja jestem.
# 40 Lepiej być daleko od krawędzi, a nie blisko.
# 17526 Kino.
# 7315 Jakaś chemia.
# 3277 Trudno, bez nóg.
# 26094 Chłopiec rzuca kamieniem i rozbija szybę.
# 12005 A chłopak na to: nic nie czułem.
# 2149 Gdzie?
# 24212 Tata już się odwrócił.
# 33636 Chłopiec biegał, wbiegł na górkę, a potem prosto na te rogi.
# 24334 Jeden z nich odbijał piłeczkę rakietką.
# 1451 Więc jest zakaz korzystania z kąpieli w wannie.
# 30059 W pniu była dziura.
# 39349 Macha łapami bezładnie.
# 8416 Widzę, że jest wąwóz.
# 3818 Nie widziałam czegoś takiego, żeby była wanna z prysznicem, a w niej ktoś się kąpał.
# 14657 Będę spacerować i pływać.
# 10821 Wiesz, pociąg nadjeżdża.
# 21562 O godzinie dziewiątej nie ma niemieckiego.
# 7112 Trzeba stać dalej od krawężnika przed przyjazdem pociągu i dopiero potem wsiąść, nie wolno stać zbyt blisko.
# 15069 Jestem w pracy.
# 21478 Nie wiem.
# 14822 Zapisuję sobie.
# 21544 Tak samo.
# 18605 Ej, ej, hej!
# 37947 Trudno powiedzieć, słowa.
# 6527 Jest taki znak z napisem “Zakaz wnoszenia własnych napojów”.
# 16981 A może następny termin masz wolny?
# 36580 Zając skacze cały czas nie zwracając na nic uwagi, skoczył w ubranie, a Myszka Miki była w szoku, bo nie wiedziała, co to jest.
# 16098 Też pracuję.
# 29076 Przychodzi pani i widzi, że okno jest czyste.
# 15486 Mam wolną sobotę.
# 35726 Królik.
# 13819 A kierowca mówi, że już jest zmęczony, pójdzie odpocząć i spać.
# 5354 Kask musi być założony równo, pośrodku czoła, bo jak będzie za nisko to nie będzie nic widać, a za wysoko do tyłu to też źle.
# 19432 Kiedy masz wolne?
# 8231 Tak to jest z tymi dziwnymi przepisami.
# 1682 Wiesz, kabel został przecięty.
# 6046 Pewnie, pewnie ci ludzie, te kobiety są przygotowane i ładnie pachną.
# 21088 Ja…
# 10424 Rozumiem.
# 28124 Już.
# 36273 W pewnym momencie… mała myszka chce strzelać z łuku, a druga myszka, duża, ma na głowie małe okrągłe jabłko.
# 28422 Przychodzi pani i płaci mu za skończoną pracę.
# 28784 Chłopiec: Tak, to mój.
# 2772 Nie, to nie o to chodzi.
# 10850 Po co trzyma teczkę w ręku?
# 10369 Zakaz wejścia we dwoje.
# 30956 Kot się zastanawia i rozgląda. Nagle wpada na pomysł.
# 33322 Chłopiec zawołał psa.
# 37877 Myszka strzela, a tata mówi: nie.
# 24779 Chaplin się przygotował i założył plecak.
# 14454 On chce ze mną wyjechać na wieś.
# 39606 Fajnie.
# 34007 „Górka” podnosi się - to jeleń! Chłopiec siada na grzbiecie i galopuje.
# 8249 A jak się jedzie to przeszkadza.
# 38590 Śmieszne to.
# 5388 Dobrze czy nie?
# 37776 Brawo!
# 19473 Szesnatego.
# 26088 Jaden kosz zniknął, gdzie jest?
# 26668 Stary, gruby pan jest na drzewie i zbiera gruszki.
# 23114 Trzech chłopców pomogło zbierać te gruszki i postawili kosz na rowerze.
# 30360 Nie wiem.
# 30636 A w środku siedzi skulona żaba.
# 22749 Ja to od ósmej do dziewiątej wieczorem nie mogę, jestem zajęta.
# 26162 Pan zauważa idących chłopców, którzy jedzą gruszki, mijają go.
# 33048 Trafia dokładnie w psa.
# 37968 Dobrze.
# 7745 Iść.
# 37392 Strzelam.
# 16316 Razem ze mną?
# 34088 Kombinował i mu się nie udało, spadł z budynku.
# 37685 Słucham Cię...
# 9562 Tam na pizzę przychodziło mnóstwo Głuchych.
# 32398 Grozi mu parasolem.
# 14217 Olsztyn, tak.
# 25178 Zaciera ręce.
# 16196 Zaraz.
# 9205 Tutaj jest dołożony trójkątny znak.
# 3855 W środku może być prąd albo bomba atomowa, lepiej, żeby ludzie nie wchodzili tam i nie robili nic głupiego, bo to jest niebezpiecznie.
# 33601 Chodzili, szukali, wołali za nią.
# 31872 Nagle wpada na pomysł.
# 7359 Pokazany kształt to oznacza, że to jest krzesło tak?
# 14276 Rano czy po południu?
# 29178 Ciekawe co będzie potem.
# 31202 Nie, cicho.
# 30955 Kot upada, a potem zdenerwowany chodzi dookoła.
# 35900 Tata poszedł do pracy.
# 36260 Za drzwiami?
# 21154 Niestety.
# 6246 Dadzą w gratisie zwymiotowaną zupę, ktoś ją zje i będzie dobrze.
# 11807 Czerwony trójkąt z wykrzyknikiem.
# 11359 Jeżeli będzie zakaz kąpieli, to ja będę śmierdzieć.
# 7656 Nie da się piłować metalu, jest twardy.
# 9598 Dziwne te słowa, nie znam ich.
# 39198 Poczekaj, muszę się zorientować.
# 10671 Całkiem dziwne.
# 4280 To jest znak ostrzegawczy.
# 29810 A to drugie, to…
# 23828 Dwa, jeden, trzy, jeden, dwa?
# 25349 Rzuca kawałkami tego w tył i trafia w twarz pana, który podszedł od tyłu.
# 26925 Tam stary pan wchodzi na drzewo po drabinie, zrywa gruszki i wkłada ja za swoje ubranie, kiedy zebrał wystarczająco dużo schodzi po drabinie na dół.
# 18699 Którego?
# 10356 Albo, albo.
# 13047 Nie wiedzieli co się dzieje.
# 10174 Na rowerze dziecko może siedzieć z tyłu tuż za siodełkiem albo za rowerem.
# 15214 O której godzinie?
# 5233 Tam w dole jest jakaś maszyna, jakiś sprzęt do zamykania.
# 33552 A ptaszek nieświadomy niczego huśta się.
# 36772 Do małego się boi.
# 21157 Można.
# 31901 Słoik pękł i rozbił się.
# 22086 Następny.
# 17176 Środa.
# 37543 Ktoś je niesie i stawia.
# 14165 O której godzinie mam przyjść do ciebie?
# 30878 Spojrzał w górę i zauważył wspaniałą, młodą, małą kaczkę.
# 25370 Dobra.
# 6024 Masz rację.
# 1736 Żółty trójkąt mówi, że trzeba uważać, żeby nie spaść na dół na nawierzchnię.
# 2825 Nie wolno mu brać prysznica, bo może jest chory?
# 926 Na peronie pociągu nie wolno stać blisko krawędzi, bo jak ktoś myje peron, to może przez przypadek popchnąć kogoś i ta osoba może spaść na tory.
# 10059 Tak.
# 28701 Dziękuje im i odjeżdża.
# 30870 Kot wypada z rury.
# 70 Ja zauważyłem, że jak ktoś w jadącym autobusie je, to nie powinno tak być.
# 32178 Dziecko spojrzało w górę, a ptak chciał je dziobnąć. Zasłoniło twarz.
# 2743 Nie wolno? Dziwne.
# 8322 Zakaz dotyczy 3 rzeczy razem: kasku, roweru i motoru.
# 18210 Coś gotuję i porządkuję, żeby było czysto.
# 8270 Nie wiem.
# 20410 Nie możemy zaplanować.
# 5488 Nie ma tego znaku w ogóle.
# 7250 Chcę zbierać drewna, więc jest zakaz piłowania siedzenia.
# 25978 Lepiej wziąć całość. Pomyślał, że lepiej wziąć wszystko.
# 22162 Ja byłem w Europie.
# 24138 Niesie go i stawia na rowerze.
# 32717 W jaki sposób?
# 7911 Ja myślę, że drugi, a tu inaczej…
# 30880 Kot zbiegł na dół.
# 21080 Rano, od dziesiątej do szóstej praca, potem szósta trzydzieści na zakupy… od szóstej trzydzieści do siódmej trzydzieści zakupy.
# 6549 Nie, nie.
# 33312 Chłopiec i pies przestraszyli się.
# 32329 Chciał wyjść i złapać ptaszka.
# 15878 Po godzinie czwartej.
# 16904 Zakupy w czwartek.
# 27271 Potem ten na drabinie znowu zbiera.
# 20912 Masz sprawy.
# 8393 Ja oglądam.
# 7665 Brak.
# 36424 Naciągnęła łuk?
# 17531 “Krzyżacy”.
# 22609 Mówiłam, że jest.
# 13593 Po wyjściu, potem wszyscy wrócili.
# 26815 Mały wybiega.
# 7576 Podobne…
# 32613 Budzą się, nie ma, zniknęła, nie ma żaby.
# 15388 Do osiemnastej, a reszta jest wolna.
# 2863 Tak, to tor, a pociąg powinien tak jechać, zresztą oglądałam to w telewizji.
# 13405 “Wołaliśmy, a ty spałeś.”
# 32102 Chłopiec nadal chodzi i szuka.
# 15308 To było dawno.
# 19821 Nie mam, mogę rano przyjść do ciebie, spotkać się o szóstej.
# 37925 Królik wskakuje do ubrania i skacze dalej.
# 21785 Super.
# 32840 A ten kot cieszy się, przygotowuje się, następnie biegnie do tego domu.
# 36270 Mysz się przestraszyła, bo zając machał rękawami ubrania.
# 29764 Ja czasami uśmiecham się migając.
# 30427 Z miłością zauważył, że żaba ma kilkoro dzieci.
# 24185 Charlie Chaplin jest z zawodu szklarzem.
# 39173 Za rogiem stoi Myszka Miki niczego nie przeczuwając.
# 19789 Napisane: trzynasty.
# 14188 Ja pierwszego kończę pracę o w pół do dziesiątej, potem wyprowadzam psa, robię zakupy.
# 16089 Też.
# 16749 Na zakupy można?
# 21704 Wtedy od czwartej trzydzieści do piątej trzydzieści mam fryzjera.
# 36225 Są strzałki na zegarze.
# 38134 Zegar dzwoni, strzela wskazówką dokładnie w dupę, dokładnie, żeby wstał.
# 32057 Nie.
# 17980 Wolne, mam wolne!
# 38358 Nie, a nie wiem.
# 28878 W cieniu drzewa stoją ukryci trzej chłopcy i przyglądają się.
# 4448 Albo to jest rower wodny?
# 21495 Jestem na zakupach…
# 10827 Oszczędzać wodę.
# 35454 A ten budzik jest zdenerwowany i strzela w pupę myszki, a ta szybko wstaje.
# 30590 Zaciekawiony ruszył w kierunku tego odgłosu.
# 6948 Mówili, żeby został.
# 8489 Tramwaj albo pociąg.
# 38947 Może mi się uda.
# 25070 Co?
# 21135 Na wsi jest dziwnie.
# 17977 Mówiłem ci!
# 36542 A myszka krzyczy.
# 13656 Oni mu odpowiadają: “Idź, idź, dobranoc! Pa, pa, dobranoc!”.
# 18010 Nie bardzo.
# 38520 Ja?
# 13857 Dobrze.
# 26326 Pierwszy, drugi, trzeci pusty.
# 8729 Tu będzie kurs języka migowego, idziemy?!
# 19760 Nie spotkamy się.
# 36503 Kto?
# 34161 Sowa wychodzi z dziupli, prosto na chłopca.
# 2982 Brawo.
# 15703 Wpadniesz do mnie do domu na kawę.
# 624 Uwaga pociąg, obok ulica i przystanek.
# 25918 Jadąc na rowerze, spogląda za siebie. Udaje mu się uciec.
# 26077 Chłopak zabiera je, dziękuje mu i odchodzi.
# 655 Uważać na truciznę, to coś ma zapach chemiczny.
# 32665 W pierwszym domu był mały kurczaczek w klatce.
# 29201 Był zaskoczony, bo urodziły się małe żabki.
# 16248 Powiedz mu.
# 19274 Jesteś wolny ósmego lutego wieczorem?
# 4962 Ja mówiłam, że jak kran jest odkręcony to można wejść?!
# 12611 Opowiadają, co się wydarzyło wczoraj.
# 39120 W ubraniu chodzi królik.
# 37353 Nie udaje się.
# 28547 Chciał zabrać jedną gruszkę.
# 38485 Tutaj.
# 23980 Jedzie i z naprzeciwka zbliża się dziewczyna, mijają się, a chłopiec gapi się na nią odwracając się.
# 26307 Zostawia.
# 8394 Tak sobie patrzę i widzę, że w trzech obrazkach kask jest skreślony, a w jednym obrazku jest dobrze.
# 3593 Wiem, tak jest nad morzem, trzeba chodzić w majtkach albo…
# 11568 Trzeba iść pomału, trzymając coś w ręku.
# 34354 Upada i rozbija przy tym słoik z żabą.
# 962 Dziwnie, że jest taki znak.
# 9786 Nie wolno iść tam i już.
# 323 Na deskorolce też w kasku.
# 36360 Płot miał kilka brakujących desek.
# 29625 Zapomniałam, ciężko mi się miga
# 3419 Jest!
# 7905 Kółko z przekreśleniem oznacza zakaz wstępu dla ludzi hetero.
# 34996 Ubrania. Bluzki czerwone, zielone, niebieskie
# 19301 Już umówiłem się z moją koleżanką na spotkanie.
# 34923 Jest uparty.
# 27501 Policjant tak samo stoi z rękoma na biodrach.
# 3931 Jest zakaz jedzenia na ulicy.
# 28474 Gruszki wypadają z kosza. Chłopiec jest zdenerwowany.
# 2851 Nie pasuje mi to.
# 28309 Ktoś, pani sąsiadka, wychodzi z domu i jest zdenerwowana z powodu pękniętej szyby, przygląda się jej.
# 9564 Dawno.
# 31745 Gdzieś w mieście w wieżowcu mieszkalnym, widać okno.
# 12140 Koniec.
# 22460 Spotkajmy się i porozmawiajmy z przyjemnością przez godzinę.
# 26810 Ten mały chłopiec czuje, że w cos uderzył, odwraca się i jest zmieszany widokiem stojącego policjanta.
# 36226 Jest daszek.
# 14757 Na kawę.
# 35610 Nie chce tego, mały ma trafić do arbuza na jego głowie.
# 3416 Biec do samochodu.
# 37946 Zapominam, dobrze?
# 25974 Koza nie słuchała właściciela i ten musiał ją ciągnąć, ale w końcu poszli.
# 32034 Krzyczy, szuka, krzyczy.
# 13834 Chcieli…
# 26701 W zamian dostaje trzy gruszki.
# 7861 Dobrze.
# 4559 Tylko tak.
# 24298 Napełnił kosz.
# 608 Przepiłowane może się załamać?
# 38321 Wiesz, był ustawiony na godzinę dziewiątą i strzelił poziomą wskazówką w jej dupę.
# 6972 Zapytaj tam.
# 3356 Tak, tak.
# 2952 Jeśli w znaku jest wykrzyknik, to znaczy, że trzeba patrzeć i uważać na nadjeżdżający pociąg.
# 9845 Nie powinno się kąpać.
# 6911 Prąd jest niebezpieczny.
# 33786 Turla się z wystawionymi tylnymi łapami prosto do kręgielni.
# 35302 Pani widzi, że zniknęły.
# 12290 Od tego czujnika na suficie.
# 23744 Mama, starsza gruba pani, do której należy dom z rozbitą szybą, wychodzi i przygląda się temu.
# 21365 Pójdźmy rano na ryby, o godzinie szóstej.
# 30683 Nie zauważył jelenia, który stał między skałami.
# 27437 Jeździe na rowerze i z naprzeciwka jedzie dziewczyna na rowerze, z warkoczami, jest młoda, w podobnym wieku jak ten chłopiec - trzynaście, piętnaście lat.
# 26055 Wchodzi na górę.
# 38787 Tata boi się, bo jabłko jest małe.
# 853 Rower nie, a nie, błąd.
# 26859 Kobieta przychodzi i dziękuje, a policjant poprawia mundur i rusza rękami.
# 2231 Upadać z wysokości, tak z wysokości.
# 6272 Światło.
# 29944 Kot podpierając się pod boki chodził tam i z powrotem.
# 18331 Dziewiętnasty?
# 39071 Królik skacze w ubraniu, jest cały schowany, łącznie z głową.
# 10423 Robią tam kupy…
# 35742 Boi się o swoje życie, czy nie dostanie się w brzuch.
# 2814 Koń ma zakaz brania prysznica.
# 1392 Nie wolno wchodzić pod prysznic.
# 13370 Walą w drzwi, ale ten kto jest w środku nic nie słyszy.
# 29115 Patrzy…
# 26803 Wyjmuje rozbite okno i wstawia nowe.
# 33277 Dwa wieżowce.
# 27098 Mały chłopiec chciał czymś rzucić, ale czuł, że jest coś nie tak i schował coś do kieszeni.
# 17791 Piątek.
# 3604 Nie wolno konia myć pod prysznicem, może trzeba wodę oszczędzać i dlatego jest zakaz.
# 29604 Kot obserwuje, obserwuje przez lornetkę.
# 14049 Ja, tak samo jak ty, nie mogę.
# 1395 Na przykład.
# 7600 Nie wiem, dla mnie to dziwne.
# 26247 Policjant biegnie za nimi.
# 10545 Zawiadamiają o zakazie.
# 9448 Stać, biec…
# 10676 Zakaz, nie.
# 37228 Zaczekać, jak to się skończy, potem zamigać, nie?
# 5667 Tak lepiej, oszczędnie się myć.
# 21541 Wycieczka do Olsztyna.
# 1536 Ten znak informuje o skażonym terenie.
# 32324 Dobrze.
# 19444 A siódmy?
# 10240 Może tam.
# 30560 Nie było żaby również w spodniach.
# 35638 Wisi na ścianie.
# 26294 Charlie Chaplin próbuje odgonić smarkacza od siebie, żeby policjant nie rozpoznał, że są wspólnikami, a smarkacz jest chuliganem.
# 32442 Aha.
# 10595 Taki skos do dołu, tama.
# 22184 A w Polsce co?
# 37941 Wszystkie są białe, a jedno czerwone.
# 22764 Ty.
# 27992 Kapelusz spada z jego głowy.
# 15639 Dwudziesty…
# 12802 “Nie słyszałem.”
# 9590 Prawda.
# 27679 Policjant zastanawia się.
# 25718 Charlie: “No, dwa złote.”
# 8960 Nie, nie można rozpoznać.
# 14303 Od ósmej do czwartej pracuję.
# 5567 Szczekają i to irytuje słyszących.
# 4528 Postawiono nowy znak.
# 23502 A pojemnik z gruszkami wypada i gruszki rozsypują się.
# 22762 Zobacz, o ósmej wyjeżdżam do Olsztyna.
# 36929 W pobliżu miski, na ścianie jest zegar, w którym wskazówki się przesuwają.
# 20042 Ok.
# 12596 Mówi do reszty: "Przepraszam. Pójdę na górę".
# 28944 Jeden kosz jest pełny, drugi pusty, ale gdzie jest trzeci pełny?
# 3049 Za chwilę samochód przejedzie.
# 19124 Nie mogę.
# 19314 Rano od ósmej do szesnastej pracuję.
# 39029 Mówiłam Ci wcześniej.
# 26117 Ten chłopak wchodzi na drabinę i zbiera gruszki z drzewa.
# 21012 Jest bałagan.
# 36843 Z naprzeciwka do tego stołka podchodzi czarny kot.
# 11626 Dobrze.
# 16794 Już, już, już, już.
# 35692 Dobrze.
# 34062 Wygląda przez okno.
# 6275 W środku domu, jak?
# 37738 Czuje ulgę i z powrotem montuje płot na jego miejscu.
# 31134 Już, już.
# 6742 Wolno tam.
# 29397 Akurat leży tam drzewo, które jest zniszczone i puste w środku.
# 14948 Widzisz?
# 17585 W niedzielę, jak nie będzie co robić…
# 24422 Koniec.
# 36083 Aha, wskazówka.
# 38899 Jabł…
# 36966 Królik w nie wskakuje i cały w nim znika, ale skacze dalej.
# 34372 No, jeleń z chłopcem na głowie biegnie, zrzuca go z siebie, a on wpada do rzeki.
# 32642 Już.
# 26348 Koniec.
# 29579 Nagle zatrzymuje się, a chłopiec wpada do wody.
# 953 Ja tak tylko myślę, pierwszy raz widzę coś takiego.
# 11592 Zakaz ich brania, zakaz piłowania.
# 14983 Zgadza się.
# 10648 Nie, tylko trzeba równo założyć, na sam środek czoła i dopiąć pod brodą.
# 24901 Przygląda, biegnie i z ukrycia chce po raz trzeci rzucić kamieniem.
# 6612 Nie mam samochodu.
# 1278 Kąpiel koni? Zakaz?
# 39107 Budzik ma wskazówki i jedną strzela w niego, w pupę.
# 39301 Prawda, fajne.
# 31856 Kot zostaje wykopany z budynku i upada, odbija się kilka razy.
# 14625 Jakieś sprawy w domu.
# 38327 Kot podchodzi do akwarium bardzo blisko.
# 5371 Nie wolno przeskakiwać.
# 1791 Tam są złe schody, są wyłożone glazurą.
# 13236 Wstał i przyszedł na śniadanie.
# 11627 Poczekaj.
# 5148 Koń.
# 13692 Kończą zwiedzać i podjeżdżają do hotelu.
# 1323 Ale jak takiego znaku w ogóle nie widziałem.
# 19454 Po pracy pójdę do domu zjeść i przyjdę na dziewiętnastą.
# 314 To bajka.
# 18609 Godzina dziesiąta nie, mogę wcześniej, a póżniej nie mogę, jestem uwiązany.
# 25191 Poszedł.
# 311 Stop.
# 25533 Policjant patrzy, jak Charlie Chaplin reperuje szybę.
# 9254 Trzeba stać bez ruchu na granicy.
# 15533 Mam pracę.
# 23353 Dobra.
# 33049 Pszczoły zaczynają atakować.
# 5657 Dziwny ten znak, dziwny.
# 5377 Może.
# 25744 Chłopiec przewraca się o kamień na drodze.  Zbolały leży na ziemi, trzymając rower.
# 31020 Kot przygląda się jej jak się huśta.
# 18189 Super.
# 22216 Tam.
# 12248 Zgubiłam się.
# 22761 Następny to piąty.
# 21401 Albo.
# 21356 Mnie wystarczy spotkanie po osiemnastej.
# 34809 Mężczyzna na spacerze zauważa brakujący kawałek płotu.
# 34191 Słyszy ten dźwięk i myśli, że żaba jest gdzieś blisko.
# 38339 Moment.
# 31062 Nie, nie, to ptaszek siedział zadowolony.
# 35285 Wyrzuca wypluwając na niego, odrzuca go.
# 32067 Są razem.
# 20744 Wtorek?
# 19998 Wieczorem.
# 3115 Nie wiem.
# 31409 Znaleźli żabę.
# 26151 W pierwszym pojemniku było pusto, w drugim też, a w trzecim było trochę, więc tam dokłożył owoce.
# 22744 Nie możesz?
# 29784 Koniec.
# 35406 Kot przechadza się. Dostrzega rybę w okrągłym akwarium. Mierzą się wzrokiem.
# 34848 Czuję, że spadnę.
# 18167 Mnie pasuje przyjść do ciebie na kawę.
# 7980 Ja.
# 23278 Chłopak jedzie na rowerze i nagle zauważa coś, a kamera zostaje skierowana na dziewczynę jadącą na rowerze.
# 6400 Jeżeli jestem spóźniony do pracy, to biegnę do samochodu, otwieram drzwi i wsiadam do niego.
# 39232 Królik wszedł do ubrania.
# 30304 Rynna.
# 27265 Dobra.
# 15273 Sprzątanie w domu.
# 15260 Super.
# 1697 Alkohol…
# 3104 Rower z dzieckiem, rower z małą przyczepką na dziecko, są też rolki i deskorolka.
# 15020 Wyjeżdżam do Olsztyna.
# 38930 Szelki, takie jak z amerykańskiego westernu. Szelki.
# 7685 Nie ma dachu, musi wytrzymać.
# 34950 Rozumiem, trafia w czoło.
# 1796 Skoro wymyślili tę tablicę, to chętnie zrobię jej zdjęcie.
# 28973 Ukrywa się za rogiem i ma ochotę na powtórkę.
# 39519 Gra na tym.
# 29203 Dawaj, dawaj…
# 9003 Czesać, polewać wodą.
# 1033 Trzeba uważać na pociąg… To jest podobne do pociągu, tylko że to drezyna na torach.
# 36287 Strzela wskazówką, bo jak inaczej.
# 35755 Wynocha.
# 5426 To jest miejsce dla muzułmanów, więc nie wolno pokazywać się stroju kąpielowym, trzeba zakryć szatą ciało i część głowy.
# 17931 Dobra.
# 14218 Wolny.
# 38463 Koniec.
# 25080 Policjant biegnie za nimi, smarkacz bardzo szybko biega.
# 26735 I strzelą kitem w tył i trafia nim w twarz policjanta.
# 13206 Strażak chciał rozwalić drzwi siekierą.
# 34900 Fajny.
# 39066 Ładnie, ładnie, ładnie.
# 6946 Mama i tata mieli złe przeczucia.
# 38636 Blisko, na ścianie wisi prostokątny zegar.
# 23674 Patrzy i widzi, że były trzy kosze, a teraz jednego nie ma.
# 9149 Wspinał się na słup wysokiego napięcia, żeby naprawić kabel.
# 1402 Nie wiem.
# 15013 Mam wizytę u fryzjera.
# 23229 Mówi policjantowi: “To już wszystko. Dobrze!” i odchodzi.
# 16090 Też, czwartek, piątek, sobota, niedziela.
# 26090 Chaplin idzie z czymś na plecach.
# 17834 Każdy słyszący dokucza Głuchym, że tak wyraziście migają.
# 32255 Ulżyło mu, był zadowolony.
# 7563 Przyznaję się, że nie znam takiego znaku.
# 11925 Nadchodzi ranek, ten na górze wstaje i jest w dobrej formie.
# 29311 Dobrze, dobrze.
# 37015 Słychać było hałas, a okazało się, że to cymbałki.
# 22968 Udawał przed policjantem, że jest w porządku.
# 19893 Niedziela na sto procent.
# 35616 Obojętnie.
# 15117 Nie.
# 943 Czyli to znaczy, że jak jest dziura w nawierzchni to można w nią spaść, lepiej ją przeskoczyć, znak uprzedza, więc ludzie nie pierwszy raz to widzą.
# 20825 Następny jest wtorek.
# 16699 A co do godziny, to ja mogę po pracy.
# 9761 Pasuje to do miejsc, gdzie jest niebezpiecznie.
# 25469 Przechodzi trzech chłopców jedzących gruszki.
# 2875 Dziwne, dlaczego jest zakaz prysznica?
# 23492 Chłopiec rozgląda się, czy nikt go nie widzi.
# 30896 Wcześniej kot połknął ten kamień i przez to miał duży brzuch.
# 38796 Okazuje się, że mały chłopiec bawi się i gra na perkusji.
# 38415 Ten ktoś wychodzi.
# 32640 W pewnym momencie, tam na dole z dziury wystaje żaba.
# 252 Aha.
# 3843 Alkohol.
# 24287 Policjant już rozumie, że byli w zmowie.
# 12066 Pozostali wracają do budynku.
# 31042 Biegnie, toczy się do domu.
# 14006 Wyjeżdżam w góry.
# 3388 Teraz ty zamigasz, a ja po tobie.
# 22846 Następny.
# 15393 Jest piątego, dziewiętnastego, dwudziestego trzeciego, dwudziestego piątego, dwudziestego szóstego.
# 18572 Aha, tu jest zapisana jakaś nazwa.
# 29995 Chłopiec wstał, przeciągnął się i popatrzył…
# 24854 Ok.
# 6870 Ja wcale…
# 33860 Wyrzucają go, ptak mu dokucza.
# 11098 Wiem, że tam jest.
# 27149 Odjeżdża na rowerze.
# 1213 Powinno być tak, że jest koło bez tła, a ten samochód jest czarny i obok jest jakiś człowiek, może zakaz dotyczy ludzi, którzy wbiegają na jezdnię.
# 15397 Pasuje.
# 22667 Dwudziestego szóstego w tych samych godzinach.
# 25715 Facet rzuca za siebie i nie zauważa policjanta.
# 3628 Zakaz kąpieli pod prysznicem.
# 22095 Żywą.
# 18794 Ja… tak, tak.
# 25490 Pobiegł.
# 27999 Akurat…
# 11405 Wiem, ten trójkąt oznacza, że jest ślisko i można się przewrócić.
# 27917 Jak...
# 7870 Oddać.
# 4029 Ale na tym rysunku drezyna nie ma rączki.
# 19143 Możemy, dobrze.
# 38654 Nie umiem strzelać z łuku.
# 3418 Jest.
# 469 Śliska.
# 14632 Chcę trochę pogadać, dla przyjemności porozmawiać.
# 8925 Dlaczego nie wolno.
# 3441 Uwaga, trzeba być bezpiecznym.
# 28108 Policjant patrzy na niego, ale nic nie robi.
# 22655 Praca, następnie sprzątanie, a wieczorem od ósmej… dwudziestej do dwudziestej pierwszej nauka tańca.
# 4202 Trzeba uważać.
# 19809 Od dziesiątej do osiemnastej pracuję.
# 1453 Jest przepis, żeby korzystac tylko z prysznica, a nie z kąpieli w wannie. Jest zakaz.
# 35914 Aha, syn grał na deseczkach.
# 2585 Nie wolno myć, czerwony pasek przekreśla koło, to śmieszne.
# 5916 To znaczy, to znaczy, że wchodzisz…
# 9702 To koń nie może tam iść.
# 15962 Proszę sprawdź w swoim kalendarzu, czy masz wolny wtorek 23 lutego.
# 10890 Ten pod spodem.
# 35052 Aha.
# 30732 Pół.
# 6887 Główny jest daleko…
# 34384 Oboje jednocześnie patrzą na siebie przez lornetki.
# 19609 Kiedy?
# 6465 Piłuje i spadnie.
# 144 Myślę, że tam, gdzie jest staw, to nie wolno pływać.
# 38647 Mały miś strzela z łuku do czegoś na głowie.
# 29917 Kaczka…
# 6515 Na pewno.
# 28811 Pan na drzewie widział go i dalej zrywał gruszki do fartucha.
# 30848 Już wiem.
# 7989 Tak samo nie można chodzić w strojach.
# 30759 Żaba była ze swym ukochanym.
# 22716 Ja to w soboty… We wszystkie soboty i niedziele jestem zajęta.
# 11601 Wybuch.
# 37518 Gra na cymbałkach.
# 26733 Policjant dziwi się, idzie dalej.
# 22098 Piękne.
# 34665 Jedzie na grzbiecie jelenia.
# 29069 Poszedł.
# 28676 Uciekają, policjant ich goni.
# 9802 Koń nie powinien się kąpać.
# 37942 Akurat królik w nie wskakuje i skacze dalej.
# 20361 O dwunastej i czternastej nie mogę.
# 32565 Stoją dwa domy naprzeciwko sobie.
# 28210 Boi się złapania przez policjanta.
# 32389 Kot zbiega na dół i leci do budynku, wktórym jest ptak, ale zostaje wyrzucony.
# 20769 To odpada.
# 2915 Zawsze przy ulicy jest taki rów.
# 28723 Na dole po wsi szła koza.
# 20363 Osiemnasty odpada.
# 1503 Znak ostrzegający o upadku.
# 33875 Toczy się i nie może wrócić.
# 20781 Wieczorem… praca.
# 6580 Można swobodnie przechodzić.
# 10955 Nie wolno chodzić w stroju kąpielowym po mieście.
# 9992 Nie wolno, jest zakaz, znak wykrzyknika.
# 10153 Spekulowali, czy to bomba czy to wina gazu, nie wiem.
# 967 Ekstra.
# 36802 Zabrała.
# 27146 Spogląda na górę, jest dobrze i pan nic nie widzi.
# 1319 Złodziej.
# 38493 Tam Myszka przygotowuje się do strzelania z łuku.
# 23115 Chłopcy odeszli, jeden z nich zauważył  czapkę i wrócił oddać ją chłopcu w zamian dostał trzy gruszki i rozeszli się.
# 36794 Otworzył drzwi i zobaczył, że dziecko gra na położonym płasko drewnianym płocie.
# 17539 Dawno.
# 24927 Spojrzał na górę, czy nikt nie widzi.
# 7162 Ale samochodom nie wolno, bo jest paliwo.
# 36492 Królik skacze, skacze z zamkniętymi oczami i wpada, wskakuje w ubranie.
# 29846 Kot leży z koszem na głowie.
# 8658 To twój charakter, ja jestem inny.
# 3108 Przekreślony, to znaczy, że jest zakaz.
# 26518 Już wszyscy się rozeszli.
# 9056 Tu nie wolno, bo nie ma możliwości podłączenia.
# 29740 Pies szczeka, a nagle pojawia się żaba.
# 32044 Mysz gryzie go w nos.
# 22288 Dwudziestego pierwszego w niedzielę mam wolne.
# 896 Powtórz.
# 30118 Kot wypada z rynny i odbija się jak piłka.
# 33945 Kot pomyślał, że może wejść przez rurę, żeby złapać ptaszka, że to może się udać.
# 879 Alkohol? Właśnie piwo i lew, nie pasuje.
# 10742 Wiem.
# 5030 A ty jak myślisz? Ja mogę myśleć inaczej.
# 12908 Przeprosił wszystkich i powiedział, że chce pójść spać.
# 5231 Tam jest niebezpieczne, może cię wessać.
# 39174 Przestraszyła się, bo myślała, że to duch.
# 6682 Ja tego nie znam.
# 31266 A tam ptak huśta się na huśtawce. Jest nadal w klatce.
# 18435 Kocham mazurskie jeziora.
# 31567 Akurat są tam też dzieci.
# 10444 Albo zakaz wejścia.
# 9753 Zero proent.
# 35826 Nie ma jeszcze.
# 4056 To jest jakiś inny znak.
# 20606 Dobrze.
# 8500 Kask krzywo założony.
# 35443 Anteną?
# 15269 W czwartek nie i w piątek nie.
# 6802 Wiesz…
# 23530 To chłopcy, jacyś koledzy.
# 30340 Kot patrzy przez lornetkę i widzi, że naprzeciwko jest mała kaczka.
# 3113 Dziwny jest ten znak, wiatrak, który dostarcza prąd, pokazany jest jako trucizna. Trzeba odejść, oddalić się od wiatraka.
# 18290 Ja wyjeżdżam nad morze.
# 30267 Jeleń podchodzi i zrzuca chłopca z siebie.
# 4672 Hamburgera wolno, a alkoholu nie wolno.
# 16929 Na imprezę.
# 33693 Kot patrzył przez lornetkę na jakiś budynek - to był hotel.
# 27510 Dobrze.
# 14501 Moment.
# 24129 Drugi.
# 11475 To jest zakaz, autobus…
# 262 Pociąg, ślisko, niebezpieczeństwo, bo wygląda, że podłoże rozdzielone kolorem, że lód zaznaczony osobno, to niebezpieczeństwo, że jest ślisko.
# 37503 Do mnie strzela, żebym wstał do pracy.
# 18332 Wyjeżdżam na działkę, na wieś.
# 470 Ostrzeżenie o mokrej powierzchni, na której można się poślizgnąć.
# 8277 Żółty trójkąt.
# 17981 Dwudziesty trzeci.
# 24836 Jeden chłopak się leni.
# 16552 Pracuję, nie mogę.
# 19736 Ja chcę… jeżeli… od poniedziałku do piątku i w sobotę ja pracuję.
# 17112 Ja w zeszłym roku byłam w kinie.
# 8596 W Polsce tego nie ma.
# 30162 Babcia otwiera i zaprasza go do środka.
# 24159 Nie jedzie na nim, tylko prowadzi go i idzie.
# 8969 Widać było, że ma piersi.
# 20341 Kiedy masz wolne?
# 37530 Chciała go wyrzucić.
# 24342 Podnieśli go i zawołali na chłopaka.
# 25797 Ktoś obcy przyjechał na rowerze.
# 7003 Uwaga, lepiej się odsunąć.
# 18145 Siódma?
# 4449 Rower wodny.
# 13 Czerwone skreślone koło, to znaczy, że nie wolno siadać na ławce i jej piłować, a potem ją ukraść.
# 11165 Znak jest postawiony na obszarze z chemikaliami albo promieniowaniem.
# 27017 Jedzie na rowerze po wyboistej drodze.
# 8285 Bez ubrań.
# 3018 Trudne.
# 21862 Proszę to zapisać, w końcu jestem zadowolony, dawno nie było takiej okazji.
# 32935 Kot.
# 25647 Nie wiem… dziewczyna albo chłopak.
# 1413 Wolno.
# 38095 Ta kukułka z zegara kradnie jabłka z misy.
# 16604 Dwudziestego.
# 8170 Skreślony jest ciepły, dymiący hamburger oraz butelka wina też jest skreślona.
# 4351 Wykrzyknik o tym informuje.
# 25606 Podchodzi do kolejnego okna.
# 32357 Zauważają się nawzajem, kot ma lornetkę i ptak ma lornetkę.
# 9303 Jeżeli…
# 23547 Chłopiec odchodzi w inne miejsce.
# 38064 Następnie…
# 35747 Aha.
# 21082 Mnie się uda z tobą spotkać.
# 17381 Ty pracujesz, a ja mam wolne.
# 25472 Prawdopodobnie ukradł go chłopiec z rowerem.
# 31520 A ten pies, ta żaba rozgląda się i po cichu wyskakuje.
# 25258 Dziecko mówi, że to tylko zabawa.
# 1043 Zabroniona jest jazda na motorze, na motorowerze i na skuterze.
# 499 Na fontannę koniom zakaz wstępu.
# 20685 Czy w środę kończysz pracę?
# 21496 Od czwartej trzydzieści do piątej trzydzieści.
# 18053 Masz wolną sobotę?
# 30323 Kot chowa się w domu.
# 12893 „Ooo, jesteś!”
# 7133 Tylko na plażę.
# 11335 Jak pada deszcz, to koń jest mokry.
# 19617 Aha…
# 12757 Chłopak mówi, że nic nie słyszał, bo mocno spał.
# 36379 Małe jabłko na głowie jest niebezpieczne, dlatego się boi.
# 16255 Mam wolne jedenastego.
# 26130 Mijają się, chłopiec traci panowanie nad kierownicą, spada mu kapelusz i przez to nie zauważa kamienia. Najeżdża na niego i przewraca się z rowerem.
# 39466 Ryba.
# 7579 Trzeba przechodzić podwójne pasy.
# 13883 Co?
# 26324 Zabrał kosz z jabłkami.
# 38821 Kolejne, za dwa dni.
# 7947 W fabryce.
# 4199 Również na dworcu PKP widać czerwoną krawędź peronu, czasami zauważam ją i wtedy proszę, żeby jej nie przekraczać tylko stać przed.
# 19597 Nie pasuje.
# 9163 Nie udało mu się i złapał.
# 11919 A tam chłopak nie zważając na nic zapalił papierosa, a unoszący się dym trafił do czujnika przeciwpożarowego.
# 34254 Są na ziemi, i patrzą się nawzajem.
# 37367 Zgadza się.
# 21362 Poczekaj.
# 1484 Zauważyłam, że  często sądy inne, tak, do spraw, tak.
# 21524 Rano.
# 32314 Mały ptaszek patrzy przez lornetkę, gdzie jest kot.
# 4519 Zakaz.
# 36231 Jest okrągły stół, a na nim biały obrus.
# 3922 Tak, nie wolno.
# 12958 Odjechali.
# 35012 Jabłko jest malutkie. Tata boi się, że może zostać trafiony w nos, czoło. Nie chce tego, jabłko jest za małe.
# 28512 Wrzucają… kolega podchodzi…
# 16153 Pracuję do osiemnastej.
# 35041 Kot…
# 23058 Zbiera je i wrzuca je do kieszeni.
# 15443 Taki sam jest…
# 9311 Tak naprawdę nie ma takiego znaku, co nie?
# 23346 Idą dalej.
# 28052 Ten mały ucieka.
# 22769 Nie dam rady przyjechać i wyjechać.
# 36325 Mała myszka strzela.
# 10388 Byłem w mieście Bolonia.
# 21513 Dobrze, luty.
# 18841 Wesele, no, nie pasuje, tak.
# 23374 Daje im trzem gruszki.
# 21933 Trzy dni. Nie powiedziałaś mi, myślałam, że jeden dzień. A tu proszę.
# 31502 Kot spada na ziemię i zły chodzi tam i z powrotem.
# 4550 Te kaski pasują na rower, dla dziecka też.
# 24617 Chłopiec mówi, że wie gdzie ma iść.
# 13247 Imprezują, migają.
# 36115 Myszka Miki, Mickey Miki.
# 37672 Ptak ukradł.
# 16886 Dlaczego? Poczekaj.
# 35947 Kukułka wyszła, zobaczyła jabłka i zabrała jak najwięcej jabłek.
# 2296 Zawsze piłują i dlatego jest zakaz?
# 14277 Ja od ósmej do czwartej pracuję.
# 38837 Aha.
# 13053 Co się stało?
# 3876 Utonięcie.
# 33559 I jest spokój.
# 26805 Zaciera ręce.
# 10308 Zapisał, że nie wolno na wysokości i koniec.
# 20801 Nie możesz.
# 2265 Kostium dwuczęściowy, będą patrzeć.
# 26259 Zapłaci?
# 8807 Tak.
# 26168 Drzewo…
# 5883 Lepiej nie dotykać.
# 596 Uwaga.
# 29103 Idzie.
# 30736 Chłopiec zmartwił się. Słoik pękł. Chłopiec wziął psa na ręce i go pogłaskał.
# 1072 Odsunąć.
# 29675 Szukali w butach.
# 11868 A Ci wszyscy znajomi na dole rozmawiają i nagle słychać alarm!
# 20432 Ja ci odpowiem.
# 10370 Ale…
# 22593 Fryzjer.
# 1829 Nie wolno, nie wolno.
# 9766 Za mała uliczka jest, znak drogowy musi tam stać.
# 28298 Daje mu całusa.
# 30473 Upadł, uderzył się i zemdlał.
# 16134 Po, dwudziesta pierwsza, dwudziesta.
# 471 Droga na gla…
# 2269 Ja byłam w szoku.
# 25911 Uciekli.
# 9058 Możliwe.
# 38038 Myszka Miki zasypia.
# 33119 Tak, widać dziurę.
# 22953 Ktoś rzucił.
# 33025 Pies wkłada do niego łeb i wypada razem ze słoikiem przez okno.
# 11567 Nie wolno biegać.
# 6193 Jak wbiegają to hamuję mocno i się denerwuję, ponieważ to ja jestem odpowiedzialny za to, trzeba patrzeć na znaki i na prędkość na zegarze w samochodzie.
# 16181 Przepraszam, nie mogę.
# 24510 Ubiera się i wychodzi.
# 38747 Postawiła na stole miskę, a kukułka zabiera owoce swoim dziobem.
# 36245 Podobnie jak duch.
# 31387 Pies, osa, i ta mała… mysz… mysz…
# 31456 Kot się turla do kręgielni.
# 25564 Charlie Chaplin mówi, żeby mały poszedł prosto, a potem w lewo.
# 21321 Która: po południu, czy rano?
# 35421 Myszka Miki nie odpuszcza i celuje w kogoś z łuku.
# 8293 Czerwone koło.
# 31436 Kot wspina się po rynnie do góry, wchodzi.
# 39127 Kaczka.
# 1992 Nie wiem.
# 37420 Nie małe.
# 11247 Ochrona, ochrona.
# 15780 Wtedy będę pomagać mu odprowadzając go do klubu.
# 25808 Jedzie rowerem.
# 16221 Nie spotkamy się.
# 33527 Chłopiec i pies wspinają się na drzewo i zauważają żabę.
# 28239 Policjant trzyma ręce na biodrach, przygląda mu się.
# 6914 Trzeba biec, uciekać.
# 21112 Dobrze.
# 428 Nie wolno brać prysznica, ponieważ on chlapie na drewnianą podłogę i drewniana podłoga może się rozkleić.
# 22316 Mam pracę.
# 32614 A ten szuka, szuka, pies sprawdza słoik, nie ma.
# 24499 Charlie Chaplin dłubie w uchu.
# 96 Najpierw się stoi, a nie biega.
# 7096 Dziecko nie rozumie, rodzice muszą złapać dziecko i nakrzyczeć, a jak ty olewasz, to dziecko nie jest winne, nie rozumie, o co chodzi w tym okrągłym znaku.
# 9370 Nie wolno tam wchodzić dzieciom, jeśli chcą wejść, to musi przyjść pani.
# 21813 To się nie opłaca.
# 7701 Zapalali i rura z pieca była ciepła.
# 22859 Było tak blisko!
# 7191 Pierwszy i ostatnie mają takie same kaski z daszkiem.
# 5654 Musi być dokładnie ustawione, bo inaczej wykolei się i trafi do twojego domu.
# 12179 Powodem alarmu było to, że chłopak palił papierosa, a dym unosił się do czujnika i uruchomił się zraszacz wody.
# 16828 Okej?
# 5504 Szybko biega, bo ma mało czasu i śpieszy się do pracy.
# 37597 Dziewczyna w czepku z falbankami wokół głowy, stawia coś na stole. A z zegara z wskazówkami wynurza się… kur... hm... kura...
# 5352 Żle założony kask czy co?
# 31258 Kot go zauważą i się cieszy.
# 34613 Na drugim obrazku dziewczynka śpi pod kołdrą.
# 13573 Rozlega się dźwięk.
# 217 Właśnie.
# 3077 W metrze jest ostrzegawczy pasek, odgradzający pasażerów od krawędzi peronu, lepiej stać przed tym paskiem.
# 11670 Dobrze.
# 11296 Nie ma takiego (znaku) upadać z taką kreską, nie ma nigdzie.
# 16431 Czwartek, dwudziestego piątego.
# 18495 We wtorek.
# 30514 Wygląda przez okno.
# 19306 Muszę odwiedzić mojego dziadka, który jest na wsi.
# 22034 Następny to wtorek?
# 18614 Teraz.
# 6418 Byłem w Izraelu.
# 37847 Ja.
# 21226 Do siódmej trzydzieści.
# 4156 Utopić.
# ...
# 19329 Jesteś wolna w piątek po godzinie szóstej?
# 410 Aha faktycznie, nie wolno piłować na siedząco, tylko na stojąco.
# 27617 Zapytał się osoby siedzącej na górze, czy może zjeść owoc.
# 33533 Kot dla przyjemności sprawdza, patrzy przez lornetkę.
# 14230 Rozumiem.
# 27558 Powtórnie wchodzi po drabinie na drzewo.
# 36715 W co innego trafił, nie wiem.
# 18573 Osiemnastego w czwartek o godzinie szóstej trzydzieści.
# 32727 To już widzi, że to nie to.
# 30568 Chłopiec pogłaskał psa.
# 36622 Zdenerwowała się, że jakiś łobuz je ukradł.
# 2816 Zakaz.
# 13049 Już wyszli.
# 16074 Od dziesiątej do szóstej trzydzieści pracuję.
# 38120 Miś, tak.
# 23609 Zdziwiła się, ale poprosiła mężczyznę z plecakiem, żeby naprawił szybę.
# 20650 Lepiej by było w czwartek.
# 11443 Ten znak jest postawiony  w mieście.
# 26430 Kto rozbił szkło?
# 26418 Koniec.
# 30372 Później chłopiec i pies budzą się i nagle zauważają…
# 4585 To człowiek.
# 24701 Skąd ci trzej mają owoce? Skąd?
# 34034 Kot połknął przez przypadek kulę, wypadł z rury i turlał się aż do budynku kręgielni.
# 14587 Jestem zajęta, nie pasuje mi.
# 21749 Możemy pójść do kina od szóstej trzydzieści do ósmej.
# 4417 Myślę, że w koście, czy w trakcie jakiegoś wykładu gdzie jest elegancko, to nie wypada jeść.
# 14418 A następnie jak mam wolne…
# 8965 Nosiła biustonosz i nie można było tego rozpoznać.
# 4041 To kanapka, hambugrer.
# 26429 A kobieta wychodzi i zauważa rozbite szkło.
# 12741 Jedne drzwi okazują się zamknięte.
# 29643 Nagle.
# 31196 Pies ciągle biegnie i szczeka, aż nagle wpada do stawu.
# 19526 Nie możesz.
# 26647 Okna już gotowe.
# 19191 Przez jedną godzinę będę zajęta u fryzjera.
# 29647 Tak, już wiem.
# 10558 Ktoś patrzy, pociąg nadjeżdża, a tu jest linia.
# 10511 Ja już opowiedziałem, wiesz…
# 22059 Ale ja chciałem pójść do kina, a żona mówi, że to głupota.
# 30718 Tak, wziął malutką żabkę.
# 30538 Urodziły się małe i w prezencie dostał jedną żabę.
# 12715 Połowa.
# 37236 Chłopak Myszka Miki i na przeciwko niego druga też Myszka, ale ma czerwone jabłko na głowie.
# 16319 Uważać na zdradę.
# 35573 Nie chce mu się wstać.
# 31176 Aha.
# 19215 Od szóstej trzydzieści wieczorem do ósmej wieczorem mam naukę języka niemieckiego.
# 24416 Siada i zaczyna się zastanawiać, drapie się po głowie.
# 30155 Kot przynosi dla małpki banana.
# 16217 Nie da się.
# 19931 Umówimy się, dobrze?
# 4516 Tak.
# 34316 Chłopak idzie spać, kładzie się, a ta żaba ucieka.
# 18631 W poniedziałek w ogóle nie mogę.
# 10101 Uwaga na niebezpieczeństwo.
# 11913 I jest pusto naokoło.
# 1135 Albo druga możliwość jest taka, że w Stanach Zjednoczonych jest znany tor wyścigów konnych i jest na nim zakaz przebywania dla koni.
# 22827 Było tak blisko!
# 37542 W misce są jabłka.
# 37304 Kot podchodzi do pływającej w akwarium ryby.
# 21222 Nie może.
# 4714 Biegnie.
# 31453 Bierze dużą kulę do bowlingu i wrzuca ją do rynny.
# 10790 Nie ma go.
# 12415 Walą do jednych drzwi.
# 22544 Niedziela.
# 8788 Spiłować drzewo to znaczy niszczyć.
# 19084 Tak, razem.
# 9934 Droga jest niebezpieczna.
# 29462 Wyrzuciła go.
# 30660 Teraz mam oglądać i zapamiętać?
# 7482 Pytam się.
# 11752 Pod pociąg.
# 39598 W zegarze siedzi kukułka, która o godzinie dwunastej zaczyna ćwierkać. widzi jak miś przyniósł jabłka to zjadł wszystko.
# 15776 To jest trudne.
# 28140 Chaplin dostaje zapłatę za wprawioną szybę.
# 14066 Nie da rady.
# 37282 Bal się, czy nie zostanie trafiony, bał się, tak?
# 8092 Podłoga jest śliska.
# 8251 Albo.
# 6306 Płynie woda, wiem.
# 1948 A liczniki za wodę nabijają, są wydatki.
# 19133 Ja pomyślę nad innym planem.
# 5447 Tak.
# 29261 Pies podpływa do brzegu chłopak wyciąga go z wody.
# 2458 Zakaz.
# 38731 Za drugim razem musi dokładnie trafić.
# 21366 Chodźmy rano o szóstej, a o dziewiątej skończymy.
# 37371 Płot.
# 32512 Pszczoły wyszli z gniazd.
# 31149 Pies jest ciekawy i podskakuje wielokrotnie.
# 36016 Patrzy i się przestraszył.
# 20996 Zapraszam.
# 37454 Tak, tak.
# 9463 Albo to chodzi o naturys… nagie osoby.
# 23451 Pojechał rowerem dalej ze skradzionym koszem, a pan na górze nadal zrywa gruszki.
# 8861 Pomarańczowe oznacza, że trzeba czekać.
# 1733 Łatwo jest się utopić.
# 27988 Chłopak jedzie rowerem.
# 24705 Trochę gruszek leży też na ziemi.
# 38587 Trafić w ramię?
# 32131 Widzi tam dwie żaby: mamę i tatę.
# 20268 Pięć procent to dodatkowe pięć złotych.
# 10206 Ja widzę, że człowiek powinen być przechylony do przodu, a jest tak, że prosto stoi, a to rower szosowy.
# 17103 Dawno.
# 27020 Wymijają się oboje.
# 9043 Tak.
# 18656 Nie mogę, nie mogę.
# 18530 Poczekaj...
# 30853 Kot schodzi na dół, wchodzi do drugiego budynku i pojawia się coś dziwnego.
# 13719 On mówi: tak, mocno spałem. Zasnąłem, drzwi na klucz zamknąłem.
# 6236 Dlaczego na tych trzech obrazkach są motory różnej wielkości i one są skreślone?
# 14656 Nie mogę, wyjeżdżam nad morze.
# 25982 Odjechał dalej na rowerze.
# 22114 Spotkanie w sklepie nie bardzo.
# 31087 Przykrywają się kołdrą i zasypiają.
# 30594 Chłopiec wziął jedną żabę do siebie.
# 610 Aha.
# 7946 Już.
# 5723 Ona zawsze ma!
# 6518 W ogóle.
# 26266 Chłopiec bawił się i pokazał palcem w jakimś kierunku, powiedział, żeby policjant tam popatrzył, a tymczasem chłopiec zwiał.
# 5351 Bez kasku, ale co?
# 30293 Ptaszek w klatce huśtał się na huśtawce.
# 29005 Koniec filmu.
# 643 Ale gdzie? W myjni samochodowej nie zauważyłem czegoś takiego, nie wiem.
# 37952 Aha.
# 2161 Krzywo założone kaski.
# 3205 To chyba jest znak, pierwsze widzę, więc tak myślę, że to jest taki znak do zabawy, który informuje o śliskim podłożu.
# 30361 Kot wspina się po długiej rynnie. Wchodzi do środka i wspina się.
# 31698 Wiesz…
# 7858 Lepiej było się umówić.
# 5333 Ale drezyna nie hałasuje jak pociąg, cicho jeździ, trzeba uważać.
# 13553 Autobus jedzie daleko.
# 22961 Akurat babcia spotkała Chaplina i chciała wykorzystać go do wymiany szyby i on się zgodził.
# 32725 Jak żabka uciekła do lasu, to wtedy zakopała się w ziemię.
# 13132 Walą w drzwi i zanim chcą toporem wyważyć drzwi, okazuje się, że ten mężczyzna zapalił papierosa i czujnik dymu wyczuł to.
# 2321 W domu, na różnych przedmiotach naklejone są informację, że nie wolno zabierać suszarki do kąpieli.
# 6545 Tak myślę.
# 25177 Staje za rogiem domu.
# 22035 Rozmowa.
# 5088 Ten pojazd jedzie, czyli to ostrzega, że jedzie.
# 6270 Może koń jest wrażliwy.
# 12543 Potem wracają zmęczeni do hotelu.
# 32576 Kot jest już na górze. Ptaszek huśta się, wiedząc, że nikogo nie ma i nikt nie napadnie na niego, jest spokojny.
# 16110 W sobotę mam wesele.
# 10691 Zakaz.
# 26353 Zrywa bez zmian.
# 35665 Kot podszedł do ryby i ją wąchał.
# 31961 Sprawdza pod ziemią, a z nory wskakuje szczur i gryzie go w nos.
# 37078 Ptaszek je jabłka.
# 27001 Wrzuca gruszki do dwóch pełnych już koszy.
# 32175 Podobny, to prawda.
# 16097 Poniedziałek.
# 30964 Koniec.
# 16744 Kiedy?
# 33148 Wychodzą z wody, idą i akurat przed nimi pojawia się leżące drzewo, oni zaglądają za nie i patrzą, że tam jest żaba.
# 39553 Koniec.
# 19294 Myślę...
# 30399 Pszczoły gonią psa, który szybko ucieka.
# 22442 Nie pasuje.
# 2199 Mogą poszukać innego miejsca, w którym mogą się wykąpać.
# 34306 Nagle znajdują parę żab.
# 7087 Ja wiem.
# 29078 Podchodzi ktoś jeszcze.
# 4139 Jest szlaban!
# 11697 Kto pomoże trzymać coś przy piłowaniu?
# 13449 Tam jest pożar.
# 10505 Pociąg słychać, a drezyny nie słychać.
# 12747 Okazało się, że chłopak palił papierosa.
# 38326 Wielki kieliszek, a w nim ryba.
# 7944 Zaraz.
# 39121 Nie chciał.
# 33447 Znaleźli je, ulżyło im.
# 27656 Stara baba przyszła i też zobaczyła pękniętą szybę.
# 20718 Dobrze, dobrze.
# 34520 Przez wodę płynie przy pomocy dziurawego pnia, to pomaga, bo on nie umie pływać.
# 38336 Mam mówić, czy bez poruszania ustami?
# 17906 Ja to bym przyszedł na chwilę, cześć i idę.
# 38035 Mam migać do niego?
# 33784 Kot połyka kulę bowlingową.
# 33943 Myśli, jak tam wejść.
# 18566 Dwudziestego siódmego?
# 32731 W końcu żabka gdzieś wyskoczyła, skakała, aż do tej skały.
# 13102 Informują, żeby wycofać się.
# 13740 Zanim uderzają w drzwi, alarm przestaje wyć.
# 32348 Wrzucił ją do rynny i strącił w ten sposób kota.
# 12836 Przerwa.
# 13183 Na szczęście nie, alarm się wyłączył, bo ktoś palił papierosy, więc mu ulżyło.
# 4172 Myślą, że ich to nie dotyczy, że wolno im kąpać zwierzęta, konia w jeziorze i to ta osoba tak samo powinna dostać mandat.
# 16008 Dobrze, spotkamy się o ósmej wieczorem.
# 37421 Dobrze, wiem, wiem.
# 22957 Kto?!
# 31276 „Jak wejść tam na górę?”
# 19134 Czy masz wolne dwudziestego pierwszego lutego?
# 11142 W tym miejscu nie wolno jeść.
# 36436 No dawaj, strzelaj.
# 11018 Śmieszne, ale nic dziwnego, bo to Polska.
# 38778 Myszka Miki kładzie na okrągły stół miskę z jabłkami.
# 17499 Ty jesteś mądry, pilnujesz, regularnie naprawiasz.
# 22832 Odpadam.
# 31587 Bomba wpadła do długiej rynny, a kot wypadł z niej na dole.
# 31185 Jeleń podnosi głowę, a chłopiec jest między jego rogami.
# 28372 Chłopiec przewrócił się z rowerem.
# 15829 Pracuję rano, a potem wpadam do dziadka.
# 29561 Wypada przez okno, słoik pęka.
# 28500 Kończy wrzucać gruszki, obok stoją dwa już pełne kosze.
# 36974 Patrzą na siebie, stykając się przez szybę pyszczkami.
# 14965 Dobrze.
# 21721 Poczekaj.
# 5442 Nie wolno myśleć.
# 29111 Potem chłopiec idzie spać.
# 1760 Nie wolno, wąwóz jest niebezpieczny.
# 22330 Na kawę mogę.
# 27511 Charlie poszedł.
# 15473 Widzisz.
# 23712 Dziecko pokazuje mu coś palcem.
# 14888 Mniej więcej dwie godziny.
# 11274 Ten z daszkiem jest prawidłowy.
# 25887 Policjant tylko kręci głową i odwraca się.
# 31445 Babcia grozi mu pięścią.
# 20846 Następny termin - piątek.
# 29942 Ptaszek wrócił.
# 11782 Na rysunku jest inaczej.
# 12295 Więc nic takiego.
# 6622 Kierowca krzyczy.
# 39592 Wspaniały.
# 8064 Uwaga, to niebezpieczne.
# 21571 Następnie imieniny.
# 18836 O godzinie szesnastej trzydzieści.
# 4038 Jest, widziałem ten znak w autobusie.
# 4863 O jeden metr dalej.
# 36215 Kolor ściany?
# 4719 Na basenie dwoje ludzi w kostiumach.
# 26003 Mężczyzna wie, że tutaj jest puste pole i nie ma wiecej gruszek. wiec skąd oni je mają.
# 23440 Tam na drzewie rosną gruszki.
# 3032 Wiatraki dają prąd.
# 21212 Wolne?
# 32826 Kot przygląda mu się i jest uśmiechnięty.
# 35317 Idzie, zimno, idzie, zimno.
# 5473 Tak jak w twoim domu, można się poślizgnąć.
# 34783 Tata miał małe jabłko i położył je sobie na głowie, by chłopak mógł zacząć strzelać.
# 2235 Uwaga, można spaść z wysokości?
# 28420 Policjant stoi.
# 36096 Jest akwarium z rybką w środku.
# 14136 To, poczekaj… piętnastego, piętnastego, o czwartej trzydzieści do piątej trzydzieści.
# 19298 Po południu, aha.
# 7702 Rura jest brązowa, metalowa i bardzo gorąca.
# 33168 Jednak ktoś go stamtąd wyrzuca.
# 39522 Przepraszam.
# 27915 Podczas mijania, chłopiec rozgląda się za nią i uderza w kamień.
# 35895 Poczekaj.
# 31581 Babcia...
# 11406 A Ty?
# 16385 Zapisuję.
# 6444 Pomyliłem się.
# 7329 Co to może być?
# 1477 Ale to alkohol, więc jakiś pijany nie może wejść.
# 21324 Ja myślałem, że czwarta.
# 30023 Krzyczał do środka.
# 10834 Tak myślę.
# 21069 Dziesiątego.
# 28550 Pan nie zauważył tego, dalej zrywał gruszki.
# 10621 Prąd.
# 7018 Inne.
# 29547 Potem chodził i znów rozmyślał co zrobić.
# 11822 Ktoś odpowiedział, że proszę bardzo, może iść.
# 24650 Uciekli do domu.
# 18132 Nie pasuje.
# 39295 Czy to jest na temat historii, czy tak normalnie?
# 20550 Dwudziesty piąty lutego?
# 35228 Zaraz, spokojnie.
# 29519 Są zadowoleni.
# 38381 Aha.
# 14204 Klub.
# 36300 Odchodzi, wraca, znowu jest mniej, jest pusto.
# 24919 Zrywa i wrzuca do kosza.
# 23520 Idą sobie, jedząc gruszki, a jeden z nich nadal odbija piłeczkę.
# 29018 Wszedł na górę.
# 2315 Czytałam o tym informacje, że nie wolno siedzieć w wannie i jednocześnie jej używać.
# 21647 Dwudziesty drugi lutego?
# 6170 To woda.
# 7877 Dużo głuchych jest zdenerwowanych. Dziwnie, że jest kierowniczką.
# 34495 Ptak… nie chłopaka boli głowa, trzyma się za głowę.
# 36183 Tata denerwuje się, poci się.
# 31 Może są zarazki.
# 4013 W biustonoszu siedzieć w restauracji?
# 31190 Jeleń się denerwuje.
# 14694 Piątek, piątego.
# 25577 Mały chłopiec — jego syn.
# 26577 Mały chłopiec wychodzi.
# 17231 W sklepie kupię chleb, jedzenie.
# 34438 Kot z bombą w środku turla się przez ulicę do jakiegoś budynku i zamyka się.
# 7093 Ludzie, choćby z żalem, ale muszą pomóc, są takie osoby, co im to jest obojętnie. Jest znak, a ktoś leży, po co to?
# 17404 Tam nie jest zapisane.
# 16553 Pracuję o dziesiątej.
# 1533 Zakaz wchodzenia do sklepu z piciem, jedzeniem.
# 35167 Patrzy ma budzik, godzina dziewiąta.
# 16867 Od osiemnastej trzydzieści do dwudziestej pierwszej trzydzieści.
# 32421 Przychodzi do klatki z ptaszkiem.
# 8626 Podobne do sanek, jest siedzenie i mini kierownica, takie sanki do zabawy.
# 15857 Numer dwa, numer drugi.
# 17091 Dobrze, super.
# 2712 Wiem, na spacerze.
# 34736 To zasysa powietrze, tak?
# 28051 Policjant patrzy na niego i zamachuje się ręką, ale chłopak ucieka.
# 28193 Syn ucieka.
# 37141 Zawołała męża i niespodziewanie spostrzegła, że nie ma jabłek.
# 8945 Osobno.
# 28199 A w tym czasie naprawiając okno, rzuca za siebie kawałki kitu.
# 15645 Piątek.
# 17613 Ja się zastanawiam.
# 31782 Ucieka.
# 35126 Myszka Miki jest uparta, nie słucha, odwraca się wystawiając dupę, odwraca się przykrywając się, ponownie zasypia, śpi.
# 29719 Chłopiec ma słój, w którym siedzi żaba.
# 577 Autobus może być.
# 33262 Skaczą wysoko.
# 24744 Akurat przechodzi trzech chłopców, jedząc gruszki.
# 6667 Nie mogłabym rozebrać się ze stroju.
# 4914 Ślisko.
# 13372 Okazało się, że ktoś w palił papierosa w pokoju i z tego powodu włączył się alarm, który uruchomił zraszacze.
# 21958 Szósta trzydzieści?
# 3947 Nie ma.
# 35916 Chwilę się zdenerwował, ale dał synowi dalej się bawić.
# 36891 Przyszedł kot i patrzy na to akwarium.
# 7529 Myślę, że może ktoś sobie idzie, i nagle może tam wpaść.
# 18958 Nie jest napisane.
# 7661 Kiedyś mówiłem Ci o chuliganach, ale nie wierzyłeś.
# 1624 Nie wolno przebiegać pomiędzy jadącymi samochodami.
# 30073 To jest film.
# 19923 Mogę piątego lutego o ósmej.
# 27084 Charlie Chaplin z małym dzieckiem zaczęli myśleć nad czymś.
# 10540 Nie.
# 22197 Grecja.
# 3540 Aa, skuter nie.
# 9756 Dziecko wpadło?
# 8691 Ogląda i obserwuje, jak my migamy byle co.
# 17960 Uu.
# 26893 Charlie odpowiada mu, że prosto, prawo, prosto.
# 8527 Uwaga!
# 237 Nie ma tego, wymyślone.
# 30602 Patrzy przez lornetkę na przeciwną stronę ulicy.
# 32534 Na początku jest tak, że stoją dwa domy naprzeciwko siebie
# 37439 Do pokoju, do pokoju wstawia.
# 22539 Wolny weekend.
# 20441 Od jedenastego, dwunasty, trzynasty, mam cztery dni urlopu.
# 33658 Chłopiec, większy, i dziewczyna, ta mniejsza.
# 29848 Już?
# 34261 Dziecko śpi, pies śpi.
# 2112 Może być ślisko, albo inne powody.
# 29854 Kot patrzy na ptaka, który się huśta.
# 4390 To wygląda jakby autobus był zniszczony od piłowania.
# 34150 Pies oferma z ciekawości wkłada łeb do słoja i rusza nim na wszystkie strony.
# 28242 Zobacz, z tyłu jest policjant.
# 29708 Już.
# 3479 Nie wolno się kąpać po prysznicem.
# 18539 Lepiej wcale.
# 7458 Upaść niespodziewanie.
# 20318 W klubie, w czwartek.
# 30592 Urodziło się dużo małych dzieci.
# 10438 Konie lubią jak się je myje.
# 33389 Długo szukali żaby.
# 2003 Komuś wpadnie coś do głowy i nie chce z mężem, chce innego.
# 25392 Co to jest? Czym on rzuca?
# 25193 Policjant macha ręką i powoli odchodzi.
# 10242 Nie znam takiego czegoś, nigdy czegoś takiego nie widziałem.
# 21078 Nie można.
# 13213 Zwiedzają, bawią się, a na końcu docierają do hotelu.
# 9136 Podobny.
# 33894 Ptak nie myśli i spokojnie się huśta.
# 38116 Zegar pomaga mi obudzić się.
# 12264 Więc idzie.
# 31084 Zapada wieczór, trzeba iść spać.
# 37212 Kot podchodzi i stykają się pyszczkami.
# 30211 Ucieka.
# 1156 Skreślone jest, to znaczy, że jest zakaz łączenia tych rzeczy.
# 31295 Chłopiec rozgląda się.
# 28532 Pan zbierał gruszki i wrzucał do czegoś przed sobą.
# 29108 Żaba siedzi w szklanym słoju.
# 2248 Biegać, zabierać, wskakiwać.
# 8740 Ciecho.
# 5562 Nie wolno się myć.
# 33504 Chłopak przestrasza się i upada.
# 15852 Wieczorem.
# 16415 Dwudziestego czwartego.
# 37393 Opowiedz.
# 11876 Ale dziwne, wszystko ucichło.
# 37283 Nic się nie bał.
# 20819 Trzy godziny… Tak, Warszawa jest wielka.
# 8287 Chyba takie znaki są nad morzem.
# 17341 Lubię wszystkie odcinki, pierwszy, drugi i trzeci, lubię, to dobry film.
# 27878 Podniósł swój rower, postawił koszyk na rower i uciekł.
# 28851 Schodzi po drabinie na dół i wysypuje wszystkie gruszki z worka na brzuchu do wielkiego kosza.
# 994 Jest rower, rower wraz z dzieckiem, rower z przyczepą i dziecko siedzące na przyczepie, rolki oraz deskorolka.
# 29129 Mam dalej oglądać.
# 4600 Są tam głusi.
# 32638 Sowa wystaje z drzewa i jest zła, pyta, co tak przeszkadza, co to jest?
# 3817 Nie ma.

# %% [markdown]
# ## Add paraphrased as new record with `ParaphraseSrcIndex`

# %%
# set src records as not paraphrases
polish_df["ParaphraseSrcIndex"] = pd.NA

# %%
AUGMENTED_PL_ANNOTATIONS_DIR = PREPROCESSED_DIR / 'augmented_pl_annotations/'
AUGMENTED_PL_ANNOTATIONS_DIR.mkdir(exist_ok=True)

parahprased_records = []
for filepath in AUGMENTED_PL_ANNOTATIONS_DIR.glob("*.txt"):
    src_record_index = int(filepath.name.split(".")[0])
    with open(filepath, 'r') as f:
        paraphrase = f.read()

    paraphrased_record_data = polish_df.loc[src_record_index].to_dict()  # copy from source record
    paraphrased_record_data["text"] = paraphrase
    paraphrased_record_data["ParaphraseSrcIndex"] = src_record_index
    
    parahprased_records.append(paraphrased_record_data)

# %%
paraphrase_df = pd.DataFrame.from_records(parahprased_records)
paraphrase_df
# Out:
#        start     end                                               text  \
# 0      23720   27520  On idzie na górę, przygotowuje kołdrę, myje si...
# 1     174560  177440                Pies popycha ul pszczół i kiwa się.
# 2     112880  114880                 Wokół jeziora rośnie wysoka trawa.
# 3     328600  329360                            Nie możesz, nie pasuje.
# 4      88880   90600                       Policjant zaczął ich ścigać.
# ...      ...     ...                                                ...
# 7920  229040  230040                         Obrazki już się skończyły.
# 7921  423040  424640                                              Prąd.
# 7922   23480   26760  On właśnie mówi im, że jest zmęczony i chce iś...
# 7923  493560  494680                          Specjalne owijki na nogi.
# 7924   66560   67880                                    Aha, to prawda.
#
#                                   doc_filepath  video_filename task_label  \
# 0               /24/K11AF15-26_24_24_alarm.eaf  K11AF15-26.mp4         24
# 1      /08/K34AF19-26_08_frog_08_frog_frog.eaf  K34AF19-26.mp4         08
# 2      /08/K71AF01-11_08_frog_08_frog_frog.eaf  K71AF01-11.mp4         08
# 3            /07/K76AF01-11_07_07_calendar.eaf  K76AF01-11.mp4         07
# 4     /17/K36BF17-26_17_kid_17_kid_chaplin.eaf  K36BF17-26.mp4         17
# ...                                        ...             ...        ...
# 7920   /08/K03AF01-21_08_frog_08_frog_frog.eaf  K03AF01-21.mp4         08
# 7921          /15/K04BF15-26_15_15_signsNO.eaf  K04BF15-26.mp4         15
# 7922            /24/K67AF13-26_24_24_alarm.eaf  K67AF13-26.mp4         24
# 7923          /15/K42BF01-15_15_15_signsNO.eaf  K42BF01-15.mp4         15
# 7924         /07/K38BF01-15_07_07_calendar.eaf  K38BF01-15.mp4         07
#
#      Paraphrase  ParaphraseSrcIndex
# 0          None               12387
# 1          None               31152
# 2          None               31719
# 3          None               18112
# 4          None               24551
# ...         ...                 ...
# 7920       None               30706
# 7921       None                 341
# 7922       None               11942
# 7923       None                6698
# 7924       None               18808
#
# [7925 rows x 8 columns]

# %%
augmented_pl_annots_df = pd.concat([polish_df, paraphrase_df], ignore_index=True)
augmented_pl_annots_df
# Out:
#         start     end                                               text  \
# 0       39040   41120                  Myślę, że mam inny pomysł, można?
# 1       41120   49680  Chyba ten znak mówi, że jak ktoś będzie spacer...
# 2       49680   55280  Trzeba przejść łukiem obok leżącego i o tym zn...
# 3       61280   66840  Okrągły znak pomaga nam, mówi, że są pasy na u...
# 4       66840   73200  Jak ktoś zobaczy, ale zignoruje ten znak, to m...
# ...       ...     ...                                                ...
# 47543  229040  230040                         Obrazki już się skończyły.
# 47544  423040  424640                                              Prąd.
# 47545   23480   26760  On właśnie mówi im, że jest zmęczony i chce iś...
# 47546  493560  494680                          Specjalne owijki na nogi.
# 47547   66560   67880                                    Aha, to prawda.
#
#                                   doc_filepath  video_filename task_label  \
# 0             /15/K66BF13-26_15_15_signsNO.eaf  K66BF13-26.mp4         15
# 1             /15/K66BF13-26_15_15_signsNO.eaf  K66BF13-26.mp4         15
# 2             /15/K66BF13-26_15_15_signsNO.eaf  K66BF13-26.mp4         15
# 3             /15/K66BF13-26_15_15_signsNO.eaf  K66BF13-26.mp4         15
# 4             /15/K66BF13-26_15_15_signsNO.eaf  K66BF13-26.mp4         15
# ...                                        ...             ...        ...
# 47543  /08/K03AF01-21_08_frog_08_frog_frog.eaf  K03AF01-21.mp4         08
# 47544         /15/K04BF15-26_15_15_signsNO.eaf  K04BF15-26.mp4         15
# 47545           /24/K67AF13-26_24_24_alarm.eaf  K67AF13-26.mp4         24
# 47546         /15/K42BF01-15_15_15_signsNO.eaf  K42BF01-15.mp4         15
# 47547        /07/K38BF01-15_07_07_calendar.eaf  K38BF01-15.mp4         07
#
#       Paraphrase ParaphraseSrcIndex
# 0            NaN                NaN
# 1            NaN                NaN
# 2            NaN                NaN
# 3            NaN                NaN
# 4            NaN                NaN
# ...          ...                ...
# 47543       None              30706
# 47544       None                341
# 47545       None              11942
# 47546       None               6698
# 47547       None              18808
#
# [47548 rows x 8 columns]

# %%
augmented_pl_annots_df.iloc[[1, 39623]]
# Out:
#        start    end                                               text  \
# 1      41120  49680  Chyba ten znak mówi, że jak ktoś będzie spacer...
# 39623  23720  27520  On idzie na górę, przygotowuje kołdrę, myje si...
#
#                            doc_filepath  video_filename task_label Paraphrase  \
# 1      /15/K66BF13-26_15_15_signsNO.eaf  K66BF13-26.mp4         15        NaN
# 39623    /24/K11AF15-26_24_24_alarm.eaf  K11AF15-26.mp4         24       None
#
#       ParaphraseSrcIndex
# 1                   <NA>
# 39623              12387

# %%
augmented_pl_annots_df.to_feather(EMBEDDINGS_DIR / 'augmented_pl_annots_df.feather')

# %% [markdown]
# ## Generate texts embeddings

# %%
herbert_tokenizer = AutoTokenizer.from_pretrained("allegro/herbert-base-cased")
herbert = AutoModel.from_pretrained("allegro/herbert-base-cased").to("cuda:0")
# Out:
# Some weights of the model checkpoint at allegro/herbert-base-cased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.sso.sso_relationship.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.sso.sso_relationship.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def get_herbert_embedding(text: str, device: str = "cuda") -> np.ndarray:
    return herbert(
        **herbert_tokenizer.encode_plus(text,
            padding='longest',
            add_special_tokens=True,
            return_tensors='pt'
        ).to(device)
    ).pooler_output.to("cpu").detach().numpy()[0]

get_herbert_embedding("Ala ma kota").shape
# Out:
# (768,)

# %%
augmented_pl_annots_wth_emb_df = augmented_pl_annots_df.copy()

augmented_pl_annots_wth_emb_df["EmbeddingModel"] = "allegro/herbert-base-cased"
# augmented_pl_annots_wth_emb_df["Embedding"] = [-np.ones(768) for _ in range(augmented_pl_annots_wth_emb_df.shape[0])]
augmented_pl_annots_wth_emb_df["Embedding"] = augmented_pl_annots_wth_emb_df["text"].progress_apply(get_herbert_embedding)

augmented_pl_annots_wth_emb_df.to_feather(EMBEDDINGS_DIR / 'augmented_pl_annots_wth_emb_df.feather')
augmented_pl_annots_wth_emb_df
# Out:
#   0%|          | 0/47548 [00:00<?, ?it/s]
#         start     end                                               text  \
# 0       39040   41120                  Myślę, że mam inny pomysł, można?
# 1       41120   49680  Chyba ten znak mówi, że jak ktoś będzie spacer...
# 2       49680   55280  Trzeba przejść łukiem obok leżącego i o tym zn...
# 3       61280   66840  Okrągły znak pomaga nam, mówi, że są pasy na u...
# 4       66840   73200  Jak ktoś zobaczy, ale zignoruje ten znak, to m...
# ...       ...     ...                                                ...
# 47543  229040  230040                         Obrazki już się skończyły.
# 47544  423040  424640                                              Prąd.
# 47545   23480   26760  On właśnie mówi im, że jest zmęczony i chce iś...
# 47546  493560  494680                          Specjalne owijki na nogi.
# 47547   66560   67880                                    Aha, to prawda.
#
#                                   doc_filepath  video_filename task_label  \
# 0             /15/K66BF13-26_15_15_signsNO.eaf  K66BF13-26.mp4         15
# 1             /15/K66BF13-26_15_15_signsNO.eaf  K66BF13-26.mp4         15
# 2             /15/K66BF13-26_15_15_signsNO.eaf  K66BF13-26.mp4         15
# 3             /15/K66BF13-26_15_15_signsNO.eaf  K66BF13-26.mp4         15
# 4             /15/K66BF13-26_15_15_signsNO.eaf  K66BF13-26.mp4         15
# ...                                        ...             ...        ...
# 47543  /08/K03AF01-21_08_frog_08_frog_frog.eaf  K03AF01-21.mp4         08
# 47544         /15/K04BF15-26_15_15_signsNO.eaf  K04BF15-26.mp4         15
# 47545           /24/K67AF13-26_24_24_alarm.eaf  K67AF13-26.mp4         24
# 47546         /15/K42BF01-15_15_15_signsNO.eaf  K42BF01-15.mp4         15
# 47547        /07/K38BF01-15_07_07_calendar.eaf  K38BF01-15.mp4         07
#
#       Paraphrase ParaphraseSrcIndex              EmbeddingModel  \
# 0            NaN               <NA>  allegro/herbert-base-cased
# 1            NaN               <NA>  allegro/herbert-base-cased
# 2            NaN               <NA>  allegro/herbert-base-cased
# 3            NaN               <NA>  allegro/herbert-base-cased
# 4            NaN               <NA>  allegro/herbert-base-cased
# ...          ...                ...                         ...
# 47543       None              30706  allegro/herbert-base-cased
# 47544       None                341  allegro/herbert-base-cased
# 47545       None              11942  allegro/herbert-base-cased
# 47546       None               6698  allegro/herbert-base-cased
# 47547       None              18808  allegro/herbert-base-cased
#
#                                                Embedding
# 0      [-0.039401535, 0.045144096, -0.07359799, 0.999...
# 1      [-0.04103174, 0.18905145, -0.2473697, 0.999101...
# 2      [-0.099419735, 0.2554967, -0.2758171, 0.996696...
# 3      [-0.23825723, -0.018337265, -0.06085317, 0.998...
# 4      [-0.12970479, 0.22667503, -0.34039426, 0.99525...
# ...                                                  ...
# 47543  [-0.078688405, 0.10844632, 0.042495422, 0.9991...
# 47544  [-0.027012182, 0.24136762, -0.04894121, 0.9986...
# 47545  [0.015946332, -0.046507165, -0.20022015, 0.998...
# 47546  [-0.25153598, 0.05548507, -0.071281515, 0.9990...
# 47547  [-0.0833914, -0.18917054, -0.17606916, 0.99899...
#
# [47548 rows x 10 columns]
