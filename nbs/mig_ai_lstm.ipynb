# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
import glob
import pandas as pd
from torch.utils.data import Dataset, DataLoader

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cuda

# %%
import glob

files = glob.glob("/content/*")
print(files[0])
# Out:
# /content/K01AF__07_123160-124680.csv

# %%
import pandas as pd

df = pd.read_csv(files[1])
df = df.drop(columns=['Unnamed: 0'])

# %%
max(df['FrameNumber'])
# Out:
# 11

# %%
frame_number = max(df['FrameNumber'])

video_seq = []
for n in range(frame_number):
  frame_df = df[df['FrameNumber']==n]

  frame_seq=[]
  for row in frame_df.iterrows():
      frame_seq.append([row[1]['X'], row[1]['Y'], row[1]['Z']])

  video_seq.append(torch.tensor(frame_seq, dtype=torch.float))

# video_seq = torch.tensor(video_seq, dtype=torch.float)

# %%
# for n in range(frame_number):
#   print(len(video_seq[n]))
# video_seq

my_tensor = torch.cat(video_seq, dim=-2)
print(my_tensor.shape)
print(my_tensor)
# Out:
# torch.Size([363, 3])
# tensor([[ 0.4203,  0.4312, -0.8396],
#         [ 0.4279,  0.3961, -0.8517],
#         [ 0.4340,  0.3908, -0.8517],
#         ...,
#         [ 0.4368,  1.5453, -0.0426],
#         [ 0.5010,  1.6314, -0.1309],
#         [ 0.4270,  1.6275, -0.2985]])

# %%
# class SequenceEmbedder(nn.Module):
#     def __init__(self, input_dim, embed_dim, hidden_dim, output_dim):
#         super(SequenceEmbedder, self).__init__()
#         self.input_dim = input_dim
#         self.hidden_dim = hidden_dim
#         self.embed_dim = embed_dim

#         self.embedding = nn.Linear(input_dim, embed_dim)
#         self.lstm = nn.LSTM(embed_dim, hidden_dim, batch_first=True)
#         self.attention = nn.Linear(hidden_dim, 1)
#         self.fc = nn.Linear(hidden_dim, output_dim)

#     def forward(self, x, lengths):
#         x = self.embedding(x)

#         # Packing the padded sequence
#         x_packed = pack_padded_sequence(x, lengths, batch_first=True, enforce_sorted=False)

#         # LSTM
#         lstm_out, _ = self.lstm(x_packed)

#         # Unpacking the sequence
#         lstm_out, _ = pad_packed_sequence(lstm_out, batch_first=True)

#         # Attention
#         attention_weights = F.softmax(self.attention(lstm_out), dim=1)
#         context_vector = torch.sum(lstm_out * attention_weights, dim=1)

#         output = self.fc(context_vector)

#         return output.reshape(16,16)


# # Example usage
# model = SequenceEmbedder(input_dim=3, embed_dim=64, hidden_dim=128, output_dim=256)

# # Example data
# sequences = [my_tensor]  # Convert to float

# # Rest of your code remains the same
# lengths = [len(seq) for seq in sequences]
# padded_sequences = torch.nn.utils.rnn.pad_sequence(sequences, batch_first=True)
# # print(padded_sequences)
# output = model(padded_sequences, lengths)

# %%
output.shape
# Out:
# torch.Size([16, 16])

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence


class MultiHeadAttention(nn.Module):
    def __init__(self, embed_size, heads):
        super(MultiHeadAttention, self).__init__()
        self.embed_size = embed_size
        self.heads = heads
        self.head_dim = embed_size // heads

        assert (
            self.head_dim * heads == embed_size
        ), "Embedding size needs to be divisible by heads"

        self.values = nn.Linear(self.head_dim, self.head_dim, bias=False)
        self.keys = nn.Linear(self.head_dim, self.head_dim, bias=False)
        self.queries = nn.Linear(self.head_dim, self.head_dim, bias=False)
        self.fc_out = nn.Linear(heads * self.head_dim, embed_size)

    def forward(self, values, keys, query, mask):
        N = query.shape[0]
        value_len, key_len, query_len = values.shape[1], keys.shape[1], query.shape[1]

        # Split the embedding into self.heads different pieces
        values = values.view(N, value_len, self.heads, self.head_dim)
        keys = keys.view(N, key_len, self.heads, self.head_dim)
        queries = query.view(N, query_len, self.heads, self.head_dim)

        values = self.values(values)
        keys = self.keys(keys)
        queries = self.queries(queries)

        # Einsum does matrix multiplication for query*keys for each training example
        # with every other training example, don't be confused by einsum
        # it's just a way to do batch matrix multiplication
        attention = torch.einsum("nqhd,nkhd->nhqk", [queries, keys])

        if mask is not None:
            attention = attention.masked_fill(mask == 0, float("-1e20"))

        attention = torch.softmax(attention / (self.embed_size ** (1 / 2)), dim=3)

        out = torch.einsum("nhql,nlhd->nqhd", [attention, values]).reshape(
            N, query_len, self.heads * self.head_dim
        )

        out = self.fc_out(out)
        return out

class SequenceEmbedder(nn.Module):
    def __init__(self, input_dim, embed_dim, hidden_dim, output_dim, num_layers=2, heads=4, dropout=0.5):
        super(SequenceEmbedder, self).__init__()
        self.input_dim = input_dim
        self.hidden_dim = hidden_dim
        self.embed_dim = embed_dim
        self.num_layers = num_layers

        self.embedding = nn.Linear(99, embed_dim)
        self.lstm = nn.LSTM(embed_dim, hidden_dim, num_layers=num_layers,
                            batch_first=True, dropout=dropout, bidirectional=True)
        self.attention = MultiHeadAttention(hidden_dim * 2, heads)
        self.layer_norm = nn.LayerNorm(hidden_dim * 2)
        self.fc1 = nn.Linear(hidden_dim * 2, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, output_dim)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, lengths, mask=None):
    # Embedding
        x = self.embedding(x)  # Shape: [batch_size, seq_len, embed_dim]

        # Pack the sequence
        x_packed = pack_padded_sequence(x, lengths, batch_first=True, enforce_sorted=False)

        # LSTM
        lstm_out, _ = self.lstm(x_packed)
        lstm_out, _ = pad_packed_sequence(lstm_out, batch_first=True)
        

        # Transform LSTM output to match attention input requirements
        # Assuming hidden_dim * 2 == embed_size, or use a Linear layer to transform
        lstm_out = lstm_out.contiguous().view(lstm_out.shape[0], lstm_out.shape[1], -1)

        attention_out = self.attention(lstm_out, lstm_out, lstm_out, mask)

        # Further processing
        output = F.relu(self.fc1(attention_out))
        output = self.fc2(output)

        return output

    

model = SequenceEmbedder(input_dim=3, embed_dim=64, hidden_dim=128, output_dim=512).to(device)

# %%
class LandmarkDataset(Dataset):
    def __init__(self, file_paths):
        self.data = []
        self.lengths = []
        for file_path in file_paths:
            print("Processing file:", file_path)  # Logging the file path
            df = pd.read_csv(file_path)
            df = df.drop(columns=['Unnamed: 0'], errors='ignore')  # Use errors='ignore' to avoid issues if the column doesn't exist

            if df.empty or 'FrameNumber' not in df.columns:
                print(f"Skipping empty or invalid file: {file_path}")
                continue

            frame_number = max(df['FrameNumber'])

            video_seq = []
            for n in range(frame_number):
                frame_df = df[df['FrameNumber'] == n]
                if frame_df.empty:
                    continue  # Skip empty frames, or you can handle them differently

                # Ensure each frame_seq tensor has consistent dimensions
                frame_seq = frame_df[['X', 'Y', 'Z']].values
                video_seq.append(torch.tensor(frame_seq, dtype=torch.float).unsqueeze(0))

            if not video_seq:
                continue  # Skip if no valid data in video

            my_tensor = torch.cat(video_seq, dim=0)  # Concatenate along the first dimension
            self.data.append(my_tensor)
            self.lengths.append(len(video_seq))

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx], self.lengths[idx] 

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

    
file_paths = glob.glob("landmarks_all/*/*")
print("Found files:", len(file_paths))

dataset = LandmarkDataset(file_paths)

# Create DataLoader
train_loader = DataLoader(dataset, batch_size=1, shuffle=True)
# Out:
csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_19520-24440.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_24440-25400.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_25400-27520.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_27520-28440.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_28440-32720.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_32720-34200.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_34600-36920.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_36920-39080.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_39080-40440.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_40440-43480.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_43480-45400.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_45400-52760.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_52760-56480.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_56480-56920.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_56920-63800.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_6280-8360.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_63800-67680.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_67680-70440.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_70440-72040.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_72040-76040.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_76040-77560.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_77560-78600.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_78600-81000.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_81000-81920.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_82720-84440.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_8360-9640.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_84440-85080.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_85080-85720.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_85720-87560.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_87560-92040.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_92040-92520.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_92520-94480.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_94480-97320.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_9640-14440.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_97320-99760.csv
# Processing file: landmarks_all\K77AF12-26\K77AF12-26__17_99760-102240.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__13_1040-6240.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__13_10960-11480.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__13_110200-111600.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__13_11480-13040.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__13_13040-15360.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__13_38400-41440.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__13_41440-42480.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__13_42480-43480.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__13_43480-45720.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__13_46400-46880.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__13_6240-10960.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__13_70560-74560.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__13_74560-78040.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__13_78040-80640.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__13_80640-82920.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__13_82920-84200.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__13_85680-86920.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__15_101400-105800.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__15_10240-11520.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__15_106560-107280.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__15_11520-13000.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__15_120320-120760.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__15_13000-14800.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__15_160480-161440.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__15_161440-165280.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__15_16320-16840.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__15_179240-180200.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__15_180200-182920.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__15_182920-184920.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__15_28520-32240.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__15_48280-48800.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__15_53440-55080.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__15_55080-58000.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__15_72960-76080.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__15_76080-78200.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__15_78800-79760.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__15_81680-82720.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__15_82720-83880.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__15_83880-86120.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__15_86120-88680.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__15_98240-99360.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_0-4200.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_12400-16000.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_16320-16640.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_16640-17240.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_17240-21920.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_21920-25400.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_25400-29840.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_29840-32200.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_32200-34200.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_34200-36800.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_36800-39400.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_39400-41000.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_41000-43640.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_4200-5680.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_43640-46680.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_46680-48000.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_48000-49400.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_49400-51160.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_51160-53000.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_53000-54080.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_54080-55120.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_55120-57920.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_5680-7720.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_57920-59480.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_59480-60720.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_60720-61480.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_64320-64800.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_64800-65400.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_7720-8160.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__17_8440-12400.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_11360-12400.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_13000-15160.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_15160-16000.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_23080-24320.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_24320-25680.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_25680-27400.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_27400-29960.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_29960-32800.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_32800-33400.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_33400-35320.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_36560-37400.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_4280-4840.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_45400-46960.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_47680-49240.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_4840-5040.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_49240-53360.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_53360-57920.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_600-4280.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_61320-63760.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_63760-64400.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_6400-9040.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_64400-64880.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_64880-69520.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_69520-70680.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_70680-71520.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_72720-76640.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_76640-78920.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_80400-83560.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_83560-84120.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_84120-85280.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_85280-86040.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_86440-88440.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_88440-88960.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_88960-89400.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_90440-92840.csv
# Processing file: landmarks_all\K77BF12-26\K77BF12-26__24_92840-93480.csv

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.MSELoss()  # Replace with the appropriate loss function
model.to(device)

num_epochs = 10  # Set the number of epochs
best_loss = float('inf')
epochs_no_improve = 0
n_epochs_stop = 5  # Number of epochs to stop after if no improvement

for epoch in range(num_epochs):
    epoch_loss = 0.0  # Track loss for each epoch

    for data, lengths in train_loader:
        
        inputs = data.squeeze(1)
        inputs = inputs.view(inputs.size(0), inputs.size(1), -1)

        # Move inputs tensor to the device
        inputs = inputs.to(device)

        # Initialize labels tensor on the device
        labels = torch.zeros(inputs.size(0), inputs.size(1), 512).to(device)

        optimizer.zero_grad()

        # Forward pass (ensure lengths is on CPU)
        outputs = model(inputs, lengths.cpu())  # Move lengths to CPU here

        # Calculate loss
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

    print(f'Epoch {epoch+1}, Loss: {loss.item()}')

    # Early stopping check
    if epoch_loss < best_loss:
        best_loss = epoch_loss
        epochs_no_improve = 0
    else:
        epochs_no_improve += 1

    if epochs_no_improve == n_epochs_stop:
        print('Early stopping triggered')
        break

# Save the model
torch.save(model.state_dict(), 'landmark_model.pth')
# Out:
# Epoch 1, Loss: 1.7483399172846248e-09
# Epoch 2, Loss: 3.827656414046032e-09
# Epoch 3, Loss: 1.3893798334052576e-09
# Epoch 4, Loss: 1.8300347903732472e-09
# Epoch 5, Loss: 8.750645208444041e-10
# Epoch 6, Loss: 5.718143736288539e-10
# Early stopping triggered

# %%
import json
from collections import defaultdict
import os
import tqdm

model = SequenceEmbedder(input_dim=3, embed_dim=64, hidden_dim=128, output_dim=512).to(device)
model.load_state_dict(torch.load('landmark_model.pth'))
model.to(device)
model.eval()

aggregated_embeddings = defaultdict(list)

with torch.no_grad():
    for i, (data, lengths) in enumerate(train_loader):
        inputs = data.squeeze(1).to(device)
        inputs = inputs.view(inputs.size(0), inputs.size(1), -1)
        outputs = model(inputs, lengths.cpu())  # Get embeddings

        file_name = os.path.basename(file_paths[i])
        video_name, frame_info = file_name.split('__')

        # Flatten and aggregate embeddings for the entire file
        for embedding in outputs:
            flat_embedding = embedding.view(-1).cpu().numpy().tolist()
            aggregated_embeddings[file_name].append(flat_embedding)

# Average the embeddings for each file
final_embeddings = []
for file_name, emb_list in aggregated_embeddings.items():
    avg_emb = [sum(e)/len(emb_list) for e in zip(*emb_list)]  # Average embedding
    final_embeddings.append({
        "CSVName": file_name,
        "Embedding": avg_emb
    })

# Save to JSON
with open('embeddings.json', 'w') as file:
    json.dump(final_embeddings, file)

# %%
import ijson

def print_first_n_items(filename, n=20):
    with open(filename, 'rb') as file:
        # Adjust the prefix according to your JSON structure
        items = ijson.items(file, 'item')
        for i, item in enumerate(items):
            if i >= n:
                break
            # Replace 'column1' and 'column2' with the actual keys of the first two columns
            print(item.get('CSVName', 'N/A'))

filename = "embeddings.json"
print_first_n_items(filename)
# Out:
# K01AF__07_122200-123160.csv
# K01AF__07_124680-126520.csv
# K01AF__07_130400-132120.csv
# K01AF__07_132120-132600.csv
# K01AF__07_132600-133840.csv
# K01AF__07_14840-18760.csv
# K01AF__07_155080-155360.csv
# K01AF__07_160600-162800.csv
# K01AF__07_165480-168720.csv
# K01AF__07_171000-172040.csv
# K01AF__07_172280-172840.csv
# K01AF__07_183840-185440.csv
# K01AF__07_189880-192480.csv
# K01AF__07_198800-200240.csv
# K01AF__07_202200-206040.csv
# K01AF__07_206040-208040.csv
# K01AF__07_20640-22360.csv
# K01AF__07_218160-218600.csv
# K01AF__07_22760-24160.csv
# K01AF__07_228960-232760.csv

# %%
import json

import jsonlines

landmarks_emb_fpath = "embeddings.json"
with open(landmarks_emb_fpath) as landmarks_emb_file:
    landmarks_embeddings = json.load(landmarks_emb_file)
    print("Loaded embeddings.json")

# landmarks_embeddings = [
#     {"CSVName": "a", "Embedding": [1, 2, 3]},
#     {"CSVName": "b", "Embedding": [4, 5, 6]},
#     {"CSVName": "c", "Embedding": [7, 8, 9]},
# ]

with jsonlines.open("./embeddings.jsonl", "w") as writer:
    for _ in range(len(landmarks_embeddings)):
        dict_ = landmarks_embeddings.pop(0)
        writer.write(dict_)
# Out:
# Loaded embeddings.json
